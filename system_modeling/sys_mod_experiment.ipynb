# %% [markdown]
# <a href="https://colab.research.google.com/github/crissyro/-algorithms-and-data-structures-course/blob/main/system_modeling/sys_mod_experiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
from scipy import stats

import re
import warnings

warnings.filterwarnings('ignore')

plt.style.use('seaborn-v0_8-pastel')
sns.set_theme(style='whitegrid')
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('data_experiment.csv')
df.drop(['Отметка времени'], axis=1, inplace=True)

print(df.shape)

df.head()
# Out:
# (221, 18)
#          Уровень обучения  Направление      Пол  Возраст  \
# 0  Бакалаврит/Специалитет  Архитектура  Мужской       21
# 1            Магистратура     Медицина  Мужской       22
# 2  Бакалаврит/Специалитет  Архитектура  Женский       19
# 3            Магистратура  Архитектура  Мужской       23
# 4            Магистратура  Архитектура  Женский       22
#
#    Оцени, насколько часто ты прокрастинируешь в учебе  \
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                                                  3
# 4                                                  5
#
#    Насколько прокрастинация мешает тебе учиться?  \
# 0                                              3
# 1                                              5
# 2                                              5
# 3                                              3
# 4                                              5
#
#    Тревожность и стресс: Я избегаю задач, потому что чувствую тревогу или стресс от них.  \
# 0                                                  5
# 1                                                  3
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    Мотивация: Я прокрастинирую, когда не вижу смысла в задании.  \
# 0                                                  2
# 1                                                  4
# 2                                                  5
# 3                                                  4
# 4                                                  1
#
#    Наличие дедлайна: Я работаю только когда приближается дедлайн.  \
# 0                                                  3
# 1                                                  5
# 2                                                  5
# 3                                                  1
# 4                                                  3
#
#    Сон: Недостаток сна снижает мою продуктивность и усиливает прокрастинацию.  \
# 0                                                  1
# 1                                                  2
# 2                                                  5
# 3                                                  4
# 4                                                  1
#
#    Социальные сети: Я часто откладываю дела, уходя в соцсети.  \
# 0                                                  3
# 1                                                  5
# 2                                                  2
# 3                                                  2
# 4                                                  3
#
#    Кофеин: Кофе/энергетики помогают мне начать работу.  \
# 0                                                  1
# 1                                                  2
# 2                                                  2
# 3                                                  2
# 4                                                  1
#
#    Рабочая среда: Мне сложно сосредоточиться в общежитии/доме/кафе и т.д.  \
# 0                                                  3
# 1                                                  5
# 2                                                  4
# 3                                                  1
# 4                                                  3
#
#    Самооценка: Я прокрастинирую, потому что боюсь сделать плохо.  \
# 0                                                  2
# 1                                                  2
# 2                                                  3
# 3                                                  3
# 4                                                  4
#
#    Усталость: Я слишком устаю, чтобы начать делать задания.  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#   Как часто ты используешь “cramming” (делаешь всё в последний момент)?  \
# 0                                             Иногда
# 1                                             Всегда
# 2                                             Иногда
# 3                                              Часто
# 4                                             Иногда
#
#                   Что ты чаще откладываешь?  \
# 0    Повседневные домашки, Курсовые/доклады
# 1  Курсовые/доклады, Подготовку к экзаменам
# 2                          Курсовые/доклады
# 3                          Курсовые/доклады
# 4                      Повседневные домашки
#
#   Опиши одной фразой, почему ты прокрастинируешь чаще всего
# 0                               Физическое истощение
# 1                              Нет внешнего контроля
# 2                            Осознанное откладывание
# 3                                               Лень
# 4                   Любая задача кажется неподъемной

# %%
column_mapping = {
    'Уровень обучения': 'education_level',
    'Направление': 'major',
    'Пол': 'gender',
    'Возраст': 'age',
    'Оцени, насколько часто ты прокрастинируешь в учебе': 'procrastination_freq',
    'Насколько прокрастинация мешает тебе учиться?': 'procrastination_impact',
    'Тревожность и стресс: Я избегаю задач, потому что чувствую тревогу или стресс от них.': 'anxiety_stress',
    'Мотивация: Я прокрастинирую, когда не вижу смысла в задании.': 'motivation',
    'Наличие дедлайна: Я работаю только когда приближается дедлайн.': 'deadline_dependency',
    'Сон: Недостаток сна снижает мою продуктивность и усиливает прокрастинацию.': 'sleep_impact',
    'Социальные сети: Я часто откладываю дела, уходя в соцсети.': 'social_media',
    'Кофеин: Кофе/энергетики помогают мне начать работу.': 'caffeine',
    'Рабочая среда: Мне сложно сосредоточиться в общежитии/доме/кафе и т.д.': 'environment',
    'Самооценка: Я прокрастинирую, потому что боюсь сделать плохо.': 'self_esteem',
    'Усталость: Я слишком устаю, чтобы начать делать задания.': 'fatigue',
    'Как часто ты используешь “cramming” (делаешь всё в последний момент)?': 'cramming_freq',
    'Что ты чаще откладываешь?': 'postponed_tasks',
    'Опиши одной фразой, почему ты прокрастинируешь чаще всего': 'procrastination_reason'
}

df = df.rename(columns=column_mapping)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221 entries, 0 to 220
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   education_level         221 non-null    object
#  1   major                   221 non-null    object
#  2   gender                  221 non-null    object
#  3   age                     221 non-null    int64
#  4   procrastination_freq    221 non-null    int64
#  5   procrastination_impact  221 non-null    int64
#  6   anxiety_stress          221 non-null    int64
#  7   motivation              221 non-null    int64
#  8   deadline_dependency     221 non-null    int64
#  9   sleep_impact            221 non-null    int64
#  10  social_media            221 non-null    int64
#  11  caffeine                221 non-null    int64
#  12  environment             221 non-null    int64
#  13  self_esteem             221 non-null    int64
#  14  fatigue                 221 non-null    int64
#  15  cramming_freq           221 non-null    object
#  16  postponed_tasks         221 non-null    object
#  17  procrastination_reason  221 non-null    object
# dtypes: int64(12), object(6)
# memory usage: 31.2+ KB

# %%
df.describe().T
# Out:
#                         count       mean       std   min   25%   50%   75%  \
# age                     221.0  19.597285  2.599964  16.0  18.0  19.0  21.0
# procrastination_freq    221.0   3.832579  1.046217   1.0   3.0   4.0   5.0
# procrastination_impact  221.0   4.502262  0.760529   2.0   4.0   5.0   5.0
# anxiety_stress          221.0   4.493213  0.742354   2.0   4.0   5.0   5.0
# motivation              221.0   3.398190  1.302025   1.0   3.0   4.0   4.0
# deadline_dependency     221.0   3.746606  1.065598   1.0   3.0   4.0   5.0
# sleep_impact            221.0   2.873303  1.152966   1.0   2.0   3.0   4.0
# social_media            221.0   3.656109  1.242915   1.0   3.0   4.0   5.0
# caffeine                221.0   2.434389  1.070893   1.0   2.0   2.0   3.0
# environment             221.0   3.497738  1.150590   1.0   3.0   4.0   4.0
# self_esteem             221.0   2.647059  1.149052   1.0   2.0   3.0   3.0
# fatigue                 221.0   4.932127  0.343656   2.0   5.0   5.0   5.0
#
#                          max
# age                     25.0
# procrastination_freq     5.0
# procrastination_impact   5.0
# anxiety_stress           5.0
# motivation               5.0
# deadline_dependency      5.0
# sleep_impact             5.0
# social_media             5.0
# caffeine                 5.0
# environment              5.0
# self_esteem              5.0
# fatigue                  5.0

# %%
df.describe(include='object').T
# Out:
#                        count unique                                   top freq
# education_level          221      3                               Колледж   91
# major                    221      7                           Архитектура   68
# gender                   221      2                               Мужской  127
# cramming_freq            221      4                                 Часто  103
# postponed_tasks          221      7                      Курсовые/доклады   60
# procrastination_reason   221     75  Социальные сети вызывают зависимость    8

# %%
df.isnull().sum()
# Out:
# education_level           0
# major                     0
# gender                    0
# age                       0
# procrastination_freq      0
# procrastination_impact    0
# anxiety_stress            0
# motivation                0
# deadline_dependency       0
# sleep_impact              0
# social_media              0
# caffeine                  0
# environment               0
# self_esteem               0
# fatigue                   0
# cramming_freq             0
# postponed_tasks           0
# procrastination_reason    0
# dtype: int64

# %% [markdown]
# <p>В нашем исследовании колонка <code>procrastination_reason</code> содержит бесценную качественную информацию — прямые ответы студентов о том, что мешает им приступать к задачам. Однако эти данные представлены в виде свободного текста, что делает их анализ сложным. Десятки уникальных ответов могут скрывать за собой всего несколько ключевых тем.</p>
# <p>Чтобы превратить этот "хаос" из отдельных фраз в структурированное знание, мы применили методы <strong>обработки естественного языка (NLP)</strong> и <strong>машинного обучения</strong>. Наша цель — автоматически сгруппировать схожие по смыслу причины и выявить основные тематические кластеры.</p>
# <p>Процесс состоял из четырех ключевых этапов:</p>
# <hr>
# <h2>Шаг 1: Очистка и подготовка текста (Препроцессинг)</h2>
# <p>Компьютер не понимает человеческий язык так, как мы. Фразы "Боюсь неудачи." и "страх провала" для него совершенно разные. Чтобы алгоритм смог уловить смысловую близость, мы должны "унифицировать" текст.</p>
# <ul>
# <li><strong>Приведение к нижнему регистру:</strong> "Лень" и "лень" становятся одним и тем же словом.</li>
# <li><strong>Удаление знаков препинания и цифр:</strong> Слово "задача." превращается в "задача".</li>
# <li><strong>Удаление стоп-слов:</strong> Мы убираем слова, не несущие уникальной смысловой нагрузки, такие как <em>"и", "в", "на", "я", "не"</em>. Они встречаются слишком часто и только мешают анализу.</li>
# <li><strong>Стемминг:</strong> Это процесс приведения слова к его основе (корню). Например, слова <code>"устал"</code>, <code>"усталость"</code>, <code>"устаю"</code> после стемминга превратятся в единую основу <code>"уста"</code>. Это позволяет алгоритму понять, что все эти слова говорят об одном и том же явлении.</li>
# </ul>
# <p><strong>Результат этапа:</strong> Каждая причина прокрастинации превращается в очищенный, "нормализованный" набор ключевых слов.</p>
# <hr>
# <h2>Шаг 2: Векторизация (Превращение слов в числа)</h2>
# <p>Математические алгоритмы, такие как кластеризация, работают с числами, а не со словами. Нам нужно представить наш очищенный текст в числовом виде. Для этого мы использовали один из самых эффективных методов — <strong>TF-IDF</strong> (Term Frequency-Inverse Document Frequency).</p>
# <ul>
# <li><strong>TF (Term Frequency):</strong> Как часто слово встречается в <em>одном конкретном ответе</em>.</li>
# <li><strong>IDF (Inverse Document Frequency):</strong> Насколько слово является <em>уникальным и важным</em> во всей совокупности ответов. Слова, которые встречаются почти в каждом ответе (например, "задача"), получают низкий вес. Редкие, но характерные слова (например, "перфекционизм") получают высокий вес.</li>
# </ul>
# <p><strong>Результат этапа:</strong> Каждая причина теперь представлена в виде числового вектора. Схожие по смыслу причины будут иметь близкие по значению векторы. По сути, мы превратили каждую фразу в <strong>точку в многомерном пространстве</strong>.</p>
# <hr>
# <h2>Шаг 3: Кластеризация (Автоматический поиск групп)</h2>
# <p>Теперь, когда все наши причины являются точками в пространстве, мы можем найти "скопления" или "сгустки" этих точек. Для этого мы использовали алгоритм <strong>K-Means</strong>.</p>
# <p>Алгоритм автоматически находит заданное количество (в нашем случае от 2 до 5) центров кластеров и группирует все точки-причины вокруг ближайшего центра. Таким образом, ответы, которые по своему смыслу (и, соответственно, по своим TF-IDF векторам) близки друг к другу, попадают в одну группу.</p>
# <p><strong>Результат этапа:</strong> Каждой причине прокрастинации присвоен номер кластера (например, 0, 1, 2...). Мы еще не знаем, <em>что</em> означают эти кластеры, но мы знаем, что внутри каждой группы собраны похожие ответы.</p>
# <hr>
# <h2>Шаг 4: Визуализация и интерпретация (Придание смысла кластерам)</h2>
# <p>Номер кластера сам по себе неинформативен. Чтобы понять, какая тема объединяет причины в каждой группе, мы визуализировали их с помощью <strong>облаков слов (Word Clouds)</strong>.</p>
# <p>Для каждого кластера было создано отдельное облако слов. В нем размер слова напрямую зависит от его важности (частоты и уникальности) внутри данной группы. Глядя на самые крупные слова в облаке, мы можем легко интерпретировать и дать название каждой теме.</p>
# <ul>
# <li>Например, если в облаке для <strong>Кластера 0</strong> мы видим крупные слова <code>"страх"</code>, <code>"неудач"</code>, <code>"ошибк"</code>, <code>"идеальн"</code>, мы можем назвать эту тему <em>"Страх неудачи и перфекционизм"</em>.</li>
# <li>Если в <strong>Кластере 1</strong> доминируют слова <code>"лень"</code>, <code>"мотивац"</code>, <code>"сил"</code>, <code>"нет"</code>, то тема — <em>"Отсутствие мотивации и энергии"</em>.</li>
# </ul>
# <p><strong>Итоговый результат:</strong> Вместо длинного списка из сотен уникальных ответов мы получаем <strong>3-5 четко выделенных, основанных на данных, категорий причин прокрастинации</strong>. Это позволяет нам глубже понять проблему и перейти от частных случаев к общим закономерностям.</p>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from wordcloud import WordCloud

import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer

nltk.download('stopwords')
stop_words = stopwords.words('russian')
stemmer = SnowballStemmer('russian')

def preprocess_text(text):
    """
    Функция для очистки и предобработки текста:
    - Удаляет все, кроме букв кириллицы
    - Приводит к нижнему регистру
    - Удаляет стоп-слова
    - Применяет стемминг
    """
    try:
        if pd.isna(text):
            return np.nan

        # Оставляем только кириллицу и пробелы
        text = re.sub(r'[^а-яё\s]', '', str(text).lower())
        # Стемминг и удаление стоп-слов
        words = [stemmer.stem(w) for w in text.split()
                if w not in stop_words and len(w) > 2]

        return ' '.join(words) if words else np.nan
    except:
        return np.nan

def cluster_and_visualize_reasons(df):
    """
    Анализирует текстовые причины прокрастинации, кластеризует их
    и визуализирует результаты в виде облаков слов.
    Не вычисляет веса, а только определяет тематические группы.
    """
    if 'procrastination_reason' not in df.columns:
        raise ValueError("В DataFrame отсутствует необходимая колонка: 'procrastination_reason'")

    # Создаем копию для безопасной работы и добавляем очищенный текст
    analysis_df = df.copy()
    analysis_df['cleaned_text'] = analysis_df['procrastination_reason'].apply(preprocess_text)

    # Отбираем только строки с валидным текстом для анализа
    valid_data = analysis_df.dropna(subset=['cleaned_text']).copy()

    # Проверяем, достаточно ли данных для кластеризации
    if len(valid_data) < 5:
        print("Недостаточно данных для кластеризации (менее 5 валидных текстовых записей).")
        return df # Возвращаем исходный DataFrame без изменений

    try:
        # Векторизация текста с помощью TF-IDF
        tfidf = TfidfVectorizer(
            max_features=200,    # Ограничиваем количество самых частых слов/фраз
            ngram_range=(1, 2),  # Учитываем как отдельные слова, так и пары слов
            min_df=2             # Игнорируем слова, которые встречаются реже, чем в 2 документах
        )
        X = tfidf.fit_transform(valid_data['cleaned_text'])

        # Определяем количество кластеров (не менее 2, не более 5)
        n_clusters = max(2, min(5, len(valid_data) // 5))
        kmeans = KMeans(n_clusters=n_clusters, random_state=42, n_init='auto')

        # Добавляем номер кластера к каждой причине
        valid_data['cluster'] = kmeans.fit_predict(X)

        # Переносим номера кластеров в основной DataFrame
        df['cluster'] = valid_data['cluster']

        # --- Визуализация кластеров ---
        plt.figure(figsize=(15, 7))
        plt.suptitle('Тематические кластеры причин прокрастинации', fontsize=16)

        sorted_clusters = sorted(valid_data['cluster'].unique())

        for i, cluster_num in enumerate(sorted_clusters):
            # Собираем весь текст из текущего кластера
            cluster_text = ' '.join(valid_data[valid_data['cluster'] == cluster_num]['cleaned_text'])

            # Считаем количество элементов в кластере
            cluster_size = len(valid_data[valid_data['cluster'] == cluster_num])

            # Генерируем облако слов
            wordcloud = WordCloud(width=800, height=500, background_color='white', colormap='viridis').generate(cluster_text)

            plt.subplot(1, len(sorted_clusters), i + 1)
            plt.imshow(wordcloud, interpolation='bilinear')
            plt.axis('off')
            plt.title(f'Кластер {cluster_num} (n={cluster_size})')

        plt.tight_layout(rect=[0, 0, 1, 0.96])
        plt.show()

    except Exception as e:
        print(f"Ошибка во время анализа текста: {str(e)}")

    return df

result_df = cluster_and_visualize_reasons(df)

print("\nРезультаты кластеризации причин:")
if 'cluster' in result_df.columns:
    print(result_df[['procrastination_reason', 'cluster']].dropna().head(15))
else:
    print("Колонка 'cluster' не была добавлена.")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Результаты кластеризации причин:
#                              procrastination_reason  cluster
# 0                              Физическое истощение        4
# 1                             Нет внешнего контроля        2
# 2                           Осознанное откладывание        2
# 3                                              Лень        2
# 4                  Любая задача кажется неподъемной        2
# 5                               Цифровая перегрузка        2
# 6                 Легко переключаюсь между задачами        2
# 7   Прокрастинирую только по неинтересным предметам        2
# 8                    Боюсь пропустить что-то важное        2
# 9                                Отсутствие энергии        2
# 10               FOMO (страх упущенной возможности)        2
# 11                Не могу контролировать свои циклы        2
# 12                         Пик продуктивности ночью        2
# 13              Подавляющее чувство ответственности        2
# 14                 Любая задача кажется неподъемной        2

# %% [markdown]
# <h1>Глубокий анализ прокрастинации: Сравнение по специальностям и уровню образования</h1>
# <hr>
# <h2>Что показывает этот график?</h2>
# <p>Этот график — мощный инструмент для визуального сравнения, который объединяет три ключевых аспекта данных в одной наглядной схеме.</p>
# <ol>
# <li>
# <strong>Распределение по специальностям (Ось X):</strong> По горизонтальной оси расположены все специальности, представленные в выборке. Это основная категория для нашего сравнения.
# </li>
# <li>
# <strong>Уровень прокрастинации (Ось Y):</strong> По вертикальной оси отложена шкала частоты прокрастинации (от 1 до 5). Каждый "ящик" на графике показывает, как распределены значения этого показателя для студентов конкретной специальности.
# </li>
# <li>
# <strong>Разделение по уровню образования (<code>hue='education_level'</code>):</strong> Это "второй уровень" нашего анализа. Внутри каждой специальности мы видим не один, а несколько "ящиков", окрашенных в разные цвета. Каждый цвет соответствует определенному уровню образования (например, Колледж, Бакалавриат, Магистратура). Это позволяет нам напрямую сравнить, например, бакалавров-архитекторов с магистрами-архитекторами.
# </li>
# </ol>
# <h3>Ключевая особенность — умная сортировка</h3>
# <p>Обратите внимание, что специальности на графике расположены не в алфавитном порядке. Они отсортированы по <strong>медианному уровню прокрастинации</strong> (от меньшего к большему). Это сделано намеренно и является лучшей практикой в визуализации данных. Такой подход моментально превращает график в <strong>рейтинг</strong>: слева находятся специальности, студенты которых в среднем прокрастинируют меньше всего, а справа — те, для кого эта проблема наиболее актуальна. Это позволяет мгновенно выявить "группы риска".</p>
# <hr>
# <h2>Как читать "ящик с усами" (Box Plot)?</h2>
# <p>Каждый цветной элемент на графике дает массу информации:</p>
# <ul>
# <li><strong>Линия внутри "ящика":</strong> Это <strong>медиана</strong>. Она делит всех студентов этой группы пополам. 50% студентов прокрастинируют меньше этого уровня, 50% — больше. Это показатель "типичного" студента.</li>
# <li><strong>Сам "ящик" (прямоугольник):</strong> Он показывает "основную массу" студентов — <strong>средние 50%</strong> (от 25-го до 75-го перцентиля). Ширина ящика говорит о том, насколько велик разброс мнений в "ядре" группы.</li>
# <li><strong>"Усы" (вертикальные линии):</strong> Они показывают почти весь диапазон значений, исключая аномальные выбросы.</li>
# <li><strong>Отдельные точки (если есть):</strong> Это <strong>выбросы</strong> — студенты, чей уровень прокрастинации аномально высок или низок по сравнению с остальной группой.</li>
# </ul>
# <hr>
# <h2>Какие выводы можно сделать?</h2>
# <p>Анализируя этот график, мы можем ответить на очень конкретные и важные вопросы:</p>
# <ul>
# <li><strong>Какие специальности наиболее подвержены прокрастинации?</strong> <em>(Смотрим на правую часть графика)</em></li>
# <li><strong>Меняется ли склонность к прокрастинации при переходе с бакалавриата на магистратуру?</strong> <em>(Сравниваем цветные ящики внутри одной специальности: поднимается ли медиана?)</em></li>
# <li><strong>Одинакова ли эта тенденция для всех специальностей?</strong> <em>(Возможно, у инженеров прокрастинация с опытом падает, а у гуманитариев — растет).</em></li>
# <li><strong>В каких группах наблюдается наибольший разброс мнений?</strong> <em>(Ищем самые "высокие" ящики с длинными усами, что говорит о неоднородности группы).</em></li>
# </ul>

# %%
plt.figure(figsize=(18, 8))
sns.boxplot(
    x='major',
    y='procrastination_freq',
    data=df,
    hue='education_level',
    order=df.groupby('major')['procrastination_freq'].median().sort_values().index
)
plt.title('Распределение уровня прокрастинации по специальностям и уровню образования', fontsize=16)
plt.xticks(rotation=15)
plt.xlabel('Специальность')
plt.ylabel('Уровень прокрастинации')
plt.legend(title='Уровень образования')
plt.tight_layout()
plt.show()

# %% [markdown]
# <h1>Карта взаимосвязей: Как все факторы влияют друг на друга?</h1>
#
# <hr>
# <h2>Что такое корреляционная матрица и как ее читать?</h2>
# <p>В основе этой визуализации лежит <strong>корреляционная матрица</strong> — таблица, где каждая строка и каждый столбец представляют один из числовых факторов нашего исследования (возраст, уровень тревоги, мотивация и т.д.). В ячейке на пересечении строки и столбца находится число — <strong>коэффициент корреляции</strong>, который показывает, насколько эти два фактора связаны.</p>
# <p>Тепловая карта превращает эту сложную таблицу в интуитивно понятную картину, используя цвет для кодирования значений. Вот как ее расшифровать:</p>
# <h3>1. Цветовая шкала (от синего к красному)</h3>
# <ul>
# <li><strong style="color: #d62728;">Теплые цвета (красный, оранжевый):</strong> Указывают на <strong>положительную корреляцию</strong>. Это означает: "чем больше одного, тем больше другого". Например, ярко-красная ячейка между <code>anxiety_stress</code> и <code>procrastination_freq</code> говорит о том, что с ростом уровня стресса растет и частота прокрастинации.</li>
# <li><strong style="color: #377eb8;">Холодные цвета (синий, голубой):</strong> Указывают на <strong>отрицательную корреляцию</strong>. Это означает: "чем больше одного, тем меньше другого". Например, темно-синяя ячейка между <code>motivation</code> и <code>procrastination_freq</code> показывает, что студенты с высокой мотивацией склонны прокрастинировать реже.</li>
# <li><strong>Нейтральные цвета (белый, светло-серый):</strong> Говорят об <strong>отсутствии линейной связи</strong>. Значения этих факторов не зависят друг от друга.</li>
# </ul>
# <h3>2. Числа в ячейках (<code>annot=True</code>)</h3>
# <p>Каждая ячейка содержит точное значение коэффициента корреляции, который варьируется от -1 до +1:</p>
# <ul>
# <li><strong>+1:</strong> Идеальная положительная связь.</li>
# <li><strong>-1:</strong> Идеальная отрицательная связь.</li>
# <li><strong>0:</strong> Полное отсутствие связи.</li>
# </ul>
# <p>Чем ближе значение к 1 (или -1), тем ярче цвет и тем сильнее связь. Значения от 0.5 и выше (или -0.5 и ниже) обычно считаются сильной корреляцией.</p>
# <h3>3. Диагональ (<code>1.00</code>)</h3>
# <p>Вы заметите, что по диагонали от левого верхнего до правого нижнего угла все ячейки имеют значение 1.00 и окрашены в самый яркий красный цвет. Это логично, ведь любая переменная идеально коррелирует сама с собой.</p>
# <hr>

# %%
corr_matrix = df.select_dtypes(include=np.number).corr()

plt.figure(figsize=(16, 12))
sns.heatmap(
    corr_matrix,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    center=0,
    linewidths=.5
)
plt.title('Корреляция факторов прокрастинации', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h1>Паутина прокрастинации: Индивидуальный профиль для каждой специальности</h1>
# <p>
#     Чтобы понять не просто <em>насколько</em>, а <em>как именно</em> прокрастинируют студенты разных направлений, мы использовали <strong>радиальные (или паутинные) диаграммы</strong>. Этот тип визуализации идеально подходит для создания "профиля" или "портрета", позволяя сравнивать несколько различных факторов для одной группы.
# </p>
# <p>
#     Для каждой специальности была построена своя диаграмма, которая отражает средние значения по ключевым показателям, связанным с прокрастинацией.
# </p>
# <hr>
#
# <h2>Как читать этот график?</h2>
# <ul>
#     <li><strong>Оси ("лучи паутины"):</strong> Каждый луч, исходящий из центра, представляет один из факторов: частоту и влияние прокрастинации, уровень тревоги, усталости, влияния соцсетей, потребления кофеина и проблем со сном.</li>
#     <li><strong>Синяя область:</strong> Это "профиль" конкретной специальности. Чем дальше эта область простирается вдоль какой-либо оси, тем выше средний балл по этому фактору для студентов данного направления. "Шипы" на профиле указывают на наиболее выраженные проблемы.</li>
#     <li><strong>Серая пунктирная линия:</strong> Это — наш <strong>эталон для сравнения</strong>. Она представляет собой усредненный профиль по <em>всем</em> студентам в выборке.</li>
# </ul>
#
# <h2>Какие выводы можно сделать?</h2>
# <p>
#     Сравнивая синюю область с серой линией, мы можем мгновенно ответить на ключевые вопросы:
# </p>
# <ol>
#     <li><strong>В чем уникальность студентов этого направления?</strong> Если синяя область заметно "выпирает" за серую линию на оси "Тревожность", значит, студенты этой специальности в среднем более тревожны, чем остальные.</li>
#     <li><strong>Каковы их сильные и слабые стороны?</strong> Если синяя область не доходит до серой линии на оси "Влияние соцсетей", это говорит о том, что для данной группы соцсети являются меньшим отвлекающим фактором.</li>
#     <li><strong>Насколько глобальна проблема?</strong> Если синяя фигура целиком больше серой, это указывает на то, что студенты данного направления в целом более подвержены негативным факторам, связанным с прокрастинацией.</li>
# </ol>
# <p>
#     Таким образом, эти графики позволяют нам создать детализированный портрет каждой специальности и понять не только общие тенденции, но и уникальные паттерны поведения и самочувствия студентов.
# </p>

# %%
def plot_radar_chart(direction):
    profile_df = df[df['major'] == direction]

    if profile_df.empty:
        print(f"Нет данных для направления: {direction}")
        return

    profile_data = profile_df.mean(numeric_only=True)

    categories = [
        'procrastination_freq', 'procrastination_impact',
        'anxiety_stress', 'fatigue', 'social_media',
        'caffeine', 'sleep_impact'
    ]

    values = profile_data[categories].values.tolist()
    values += values[:1]

    num_vars = len(categories)
    angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
    angles += angles[:1]

    fig = go.Figure()

    fig.add_trace(go.Scatterpolar(
        r=values,
        theta=categories + [categories[0]],
        fill='toself',
        name=direction,
        line=dict(color='royalblue', width=3),
        fillcolor='rgba(65, 105, 225, 0.4)'
    ))

    avg_values = df[categories].mean().values.tolist()
    avg_values += avg_values[:1]

    fig.add_trace(go.Scatterpolar(
        r=avg_values,
        theta=categories + [categories[0]],
        name='Средние значения',
        line=dict(color='gray', dash='dot', width=2),
        opacity=0.6
    ))

    fig.update_layout(
        polar=dict(
            radialaxis=dict(
                visible=True,
                range=[0, 5],
            ),
            angularaxis=dict(
                tickfont=dict(size=12),
                gridcolor='lightgray'
            ),
        ),
        title=dict(
            text=f'Профиль прокрастинации: {direction}',
            x=0.5,
            font=dict(size=20, family='Arial')
        ),
        showlegend=True,
        height=600,
        width=800,
        paper_bgcolor='white',
        plot_bgcolor='white'
    )

    fig.show()

unique_majors = df['major'].unique()

for direction in unique_majors:
    plot_radar_chart(direction)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a2fedd0b-050a-4182-a824-2bee4944eff4" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a2fedd0b-050a-4182-a824-2bee4944eff4")) {                    Plotly.newPlot(                        "a2fedd0b-050a-4182-a824-2bee4944eff4",                        [{"fill":"toself","fillcolor":"rgba(65, 105, 225, 0.4)","line":{"color":"royalblue","width":3},"name":"Архитектура","r":[3.8970588235294117,4.573529411764706,4.764705882352941,4.985294117647059,3.2941176470588234,2.161764705882353,2.8529411764705883,3.8970588235294117],"theta":["procrastination_freq","procrastination_impact","anxiety_stress","fatigue","social_media","caffeine","sleep_impact","procrastination_freq"],"type":"scatterpolar"},{"line":{"color":"gray","dash":"dot","width":2},"name":"Средние значения","opacity":0.6,"r":[3.832579185520362,4.502262443438914,4.493212669683258,4.932126696832579,3.6561085972850678,2.434389140271493,2.8733031674208145,3.832579185520362],"theta":["procrastination_freq","procrastination_impact","anxiety_stress","fatigue","social_media","caffeine","sleep_impact","procrastination_freq"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3b7fb460-fbdd-4108-9e9f-a8ffefe90ccf" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3b7fb460-fbdd-4108-9e9f-a8ffefe90ccf")) {                    Plotly.newPlot(                        "3b7fb460-fbdd-4108-9e9f-a8ffefe90ccf",                        [{"fill":"toself","fillcolor":"rgba(65, 105, 225, 0.4)","line":{"color":"royalblue","width":3},"name":"Медицина","r":[3.533333333333333,4.133333333333334,4.533333333333333,5.0,3.7333333333333334,2.4,1.9333333333333333,3.533333333333333],"theta":["procrastination_freq","procrastination_impact","anxiety_stress","fatigue","social_media","caffeine","sleep_impact","procrastination_freq"],"type":"scatterpolar"},{"line":{"color":"gray","dash":"dot","width":2},"name":"Средние значения","opacity":0.6,"r":[3.832579185520362,4.502262443438914,4.493212669683258,4.932126696832579,3.6561085972850678,2.434389140271493,2.8733031674208145,3.832579185520362],"theta":["procrastination_freq","procrastination_impact","anxiety_stress","fatigue","social_media","caffeine","sleep_impact","procrastination_freq"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoor ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5a4da464-0b28-4591-ad57-348ffc2a1713" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5a4da464-0b28-4591-ad57-348ffc2a1713")) {                    Plotly.newPlot(                        "5a4da464-0b28-4591-ad57-348ffc2a1713",                        [{"fill":"toself","fillcolor":"rgba(65, 105, 225, 0.4)","line":{"color":"royalblue","width":3},"name":"IT","r":[3.9791666666666665,4.479166666666667,4.458333333333333,4.875,4.166666666666667,3.0,2.9166666666666665,3.9791666666666665],"theta":["procrastination_freq","procrastination_impact","anxiety_stress","fatigue","social_media","caffeine","sleep_impact","procrastination_freq"],"type":"scatterpolar"},{"line":{"color":"gray","dash":"dot","width":2},"name":"Средние значения","opacity":0.6,"r":[3.832579185520362,4.502262443438914,4.493212669683258,4.932126696832579,3.6561085972850678,2.434389140271493,2.8733031674208145,3.832579185520362],"theta":["procrastination_freq","procrastination_impact","anxiety_stress","fatigue","social_media","caffeine","sleep_impact","procrastination_freq"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4504097e-0aa5-44fe-a0d6-63025a1620a0" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4504097e-0aa5-44fe-a0d6-63025a1620a0")) {                    Plotly.newPlot(                        "4504097e-0aa5-44fe-a0d6-63025a1620a0",                        [{"fill":"toself","fillcolor":"rgba(65, 105, 225, 0.4)","line":{"color":"royalblue","width":3},"name":"Экономист и менеджер","r":[3.6551724137931036,4.413793103448276,4.241379310344827,4.896551724137931,3.5517241379310347,2.3793103448275863,2.8275862068965516,3.6551724137931036],"theta":["procrastination_freq","procrastination_impact","anxiety_stress","fatigue","social_media","caffeine","sleep_impact","procrastination_freq"],"type":"scatterpolar"},{"line":{"color":"gray","dash":"dot","width":2},"name":"Средние значения","opacity":0.6,"r":[3.832579185520362,4.502262443438914,4.493212669683258,4.932126696832579,3.6561085972850678,2.434389140271493,2.8733031674208145,3.832579185520362],"theta":["procrastination_freq","procrastination_impact","anxiety_stress","fatigue","social_media","caffeine","sleep_impact","procrastination_freq"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10, ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3e943681-5665-4654-bd1a-74976f42e31c" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3e943681-5665-4654-bd1a-74976f42e31c")) {                    Plotly.newPlot(                        "3e943681-5665-4654-bd1a-74976f42e31c",                        [{"fill":"toself","fillcolor":"rgba(65, 105, 225, 0.4)","line":{"color":"royalblue","width":3},"name":"Инженерия","r":[3.727272727272727,4.454545454545454,4.454545454545454,5.0,3.6818181818181817,2.8181818181818183,3.227272727272727,3.727272727272727],"theta":["procrastination_freq","procrastination_impact","anxiety_stress","fatigue","social_media","caffeine","sleep_impact","procrastination_freq"],"type":"scatterpolar"},{"line":{"color":"gray","dash":"dot","width":2},"name":"Средние значения","opacity":0.6,"r":[3.832579185520362,4.502262443438914,4.493212669683258,4.932126696832579,3.6561085972850678,2.434389140271493,2.8733031674208145,3.832579185520362],"theta":["procrastination_freq","procrastination_impact","anxiety_stress","fatigue","social_media","caffeine","sleep_impact","procrastination_freq"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scat ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a10940ca-cb05-461a-8b6e-d4f5a1ffac9d" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a10940ca-cb05-461a-8b6e-d4f5a1ffac9d")) {                    Plotly.newPlot(                        "a10940ca-cb05-461a-8b6e-d4f5a1ffac9d",                        [{"fill":"toself","fillcolor":"rgba(65, 105, 225, 0.4)","line":{"color":"royalblue","width":3},"name":"Лингвистика","r":[3.909090909090909,4.590909090909091,4.454545454545454,4.909090909090909,3.9545454545454546,2.0454545454545454,3.1818181818181817,3.909090909090909],"theta":["procrastination_freq","procrastination_impact","anxiety_stress","fatigue","social_media","caffeine","sleep_impact","procrastination_freq"],"type":"scatterpolar"},{"line":{"color":"gray","dash":"dot","width":2},"name":"Средние значения","opacity":0.6,"r":[3.832579185520362,4.502262443438914,4.493212669683258,4.932126696832579,3.6561085972850678,2.434389140271493,2.8733031674208145,3.832579185520362],"theta":["procrastination_freq","procrastination_impact","anxiety_stress","fatigue","social_media","caffeine","sleep_impact","procrastination_freq"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity": ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fc6ff9c3-719a-4bd9-a0b8-18719fd35c2a" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fc6ff9c3-719a-4bd9-a0b8-18719fd35c2a")) {                    Plotly.newPlot(                        "fc6ff9c3-719a-4bd9-a0b8-18719fd35c2a",                        [{"fill":"toself","fillcolor":"rgba(65, 105, 225, 0.4)","line":{"color":"royalblue","width":3},"name":"Психология","r":[3.764705882352941,4.705882352941177,4.0,4.823529411764706,3.3529411764705883,2.0588235294117645,2.8823529411764706,3.764705882352941],"theta":["procrastination_freq","procrastination_impact","anxiety_stress","fatigue","social_media","caffeine","sleep_impact","procrastination_freq"],"type":"scatterpolar"},{"line":{"color":"gray","dash":"dot","width":2},"name":"Средние значения","opacity":0.6,"r":[3.832579185520362,4.502262443438914,4.493212669683258,4.932126696832579,3.6561085972850678,2.434389140271493,2.8733031674208145,3.832579185520362],"theta":["procrastination_freq","procrastination_impact","anxiety_stress","fatigue","social_media","caffeine","sleep_impact","procrastination_freq"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"sc ...

# %% [markdown]
# <hr>
#
# <h2>Что мы видим на графиках?</h2>
# <ul>
#     <li><strong>Распределение по полу:</strong> Этот график показывает, сколько мужчин и женщин участвовало в опросе. Длина столбца прямо пропорциональна количеству респондентов в каждой группе. Это позволяет нам оценить гендерный баланс выборки.</li>
#     <li><strong>Распределение по уровню образования:</strong> Аналогично, второй график демонстрирует, сколько студентов с каждого уровня образования (Колледж, Бакалавриат/Специалитет, Магистратура) мы опросили.</li>
# </ul>
#
# <h2>Зачем это нужно?</h2>
# <p>
#     Анализ этих распределений помогает нам понять:
# </p>
# <ul>
#     <li><strong>Сбалансированность выборки:</strong> Если одна из групп (например, женщины или бакалавры) значительно преобладает, мы должны быть осторожны, обобщая выводы на всю популяцию студентов.</li>
#     <li><strong>Контекст для дальнейшего анализа:</strong> Знание состава аудитории помогает правильно интерпретировать последующие результаты. Например, если большинство респондентов — магистры, то и средние показатели будут в большей степени отражать их опыт.</li>
# </ul>
# <p>
#     Эти простые, но важные диаграммы служат отправной точкой нашего исследования, обеспечивая прозрачность и контекст для всех последующих находок.
# </p>

# %%
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
sns.countplot(y=df['gender'], order=df['gender'].value_counts().index, palette='viridis')
plt.title('Распределение респондентов по полу')
plt.xlabel('Количество')
plt.ylabel('Пол')

plt.subplot(1, 2, 2)
sns.countplot(y=df['education_level'], order=df['education_level'].value_counts().index, palette='plasma')
plt.title('Распределение по уровню образования')
plt.xlabel('Количество')
plt.ylabel('Уровень образования')

plt.tight_layout()
plt.show()

# %% [markdown]
# <h1>Возрастной срез: Распределение студентов по возрасту</h1>
#
# <hr>
#
# <h2>Как читать этот график?</h2>
# <ul>
#     <li><strong>Столбцы (bins):</strong> Вся шкала возрастов разбита на равные интервалы. Высота каждого столбца показывает, сколько студентов попало в данный возрастной диапазон.</li>
#     <li><strong>Пик графика:</strong> Самый высокий столбец указывает на наиболее часто встречающийся возраст (или возрастной интервал) в нашей выборке.</li>
#     <li><strong>Плавная линия (KDE-кривая):</strong> Это линия ядерной оценки плотности. Она сглаживает гистограмму и помогает лучше увидеть общую форму распределения, игнорируя случайные "шумы".</li>
# </ul>
#
# <h2>Какие выводы можно сделать?</h2>
# <p>
#     Гистограмма возраста позволяет нам понять:
# </p>
# <ol>
#     <li><strong>Ядро аудитории:</strong> Мы можем четко определить основной возраст наших респондентов (например, 19-22 года).</li>
#     <li><strong>Форма распределения:</strong> Является ли оно симметричным? Или "скошено" в сторону более молодых или более взрослых студентов? Это может быть связано с преобладанием студентов определенных курсов.</li>
#     <li><strong>Наличие разных групп:</strong> Несколько пиков на графике могли бы указывать на наличие в выборке нескольких различных возрастных групп (например, студенты, поступившие сразу после школы, и те, кто получает второе высшее образование).</li>
# </ol>
# <p>
#     Этот график завершает наш демографический анализ, давая полное представление о том, кого мы изучаем.
# </p>

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['age'], bins=15, kde=True, color='skyblue')
plt.title('Распределение респондентов по возрасту')
plt.xlabel('Возраст')
plt.ylabel('Количество')
plt.show()

# %% [markdown]
# <h1>Масштаб проблемы: Насколько сильно и часто студенты прокрастинируют?</h1>
#
# <hr>
#
# <h2>Что мы видим на графиках?</h2>
# <ul>
#     <li><strong>Частота прокрастинации:</strong> Первый график отвечает на вопрос "Как часто вы прокрастинируете?". Высота столбцов показывает, сколько студентов выбрали ту или иную оценку, где 1 — "очень редко", а 5 — "почти всегда".</li>
#     <li><strong>Влияние прокрастинации:</strong> Второй график иллюстрирует ответы на вопрос "Насколько прокрастинация мешает вам?". Здесь 1 означает "совсем не мешает", а 5 — "очень мешает".</li>
# </ul>
#
# <h2>Как их интерпретировать?</h2>
# <p>
#     Ключ к пониманию этих графиков — это <strong>форма распределения</strong>.
# </p>
# <ul>
#     <li><strong>Смещение вправо (высокие столбцы у оценок 4 и 5):</strong> Если большинство респондентов выбирают высокие оценки, это является прямым свидетельством того, что прокрастинация — это частая и серьезная проблема для большинства опрошенных студентов.</li>
#     <li><strong>Смещение влево (высокие столбцы у оценок 1 и 2):</strong> Такая картина говорила бы о том, что проблема не является массовой.</li>
#     <li><strong>Нормальное распределение ("горка" в центре):</strong> Указывает на то, что большинство студентов сталкиваются с прокрастинацией на среднем уровне.</li>
# </ul>
# <p>
#     Эти два графика — это "пульс" нашего исследования. Они дают прямое и недвусмысленное понимание того, насколько актуальна и болезненна тема прокрастинации для целевой аудитории.
# </p>

# %%
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
sns.countplot(x=df['procrastination_freq'], palette='coolwarm')
plt.title('Как часто вы прокрастинируете?')
plt.xlabel('Оценка (1 - Очень редко, 5 - Почти всегда)')
plt.ylabel('Количество студентов')

plt.subplot(1, 2, 2)
sns.countplot(x=df['procrastination_impact'], palette='coolwarm')
plt.title('Насколько прокрастинация мешает вам?')
plt.xlabel('Оценка (1 - Совсем не мешает, 5 - Очень мешает)')
plt.ylabel('Количество студентов')

plt.tight_layout()
plt.show()

# %% [markdown]
# <h1>В поисках закономерностей: Сравниваем прокрастинацию по группам</h1>
#
# <hr>
#
# <h2>Что мы видим на графиках?</h2>
# <p>
#     Мы построили два сравнительных графика:
# </p>
# <ol>
#     <li><strong>Прокрастинация и пол:</strong> Этот график напрямую сравнивает распределение частоты прокрастинации между мужчинами и женщинами.</li>
#     <li><strong>Прокрастинация и уровень образования:</strong> Здесь мы сравниваем студентов колледжей, бакалавриата и магистратуры.</li>
# </ol>
#
# <h3>Как читать "ящик с усами"?</h3>
# <ul>
#     <li><strong>Линия внутри "ящика":</strong> Это <strong>медиана</strong> — "типичное" значение. 50% студентов группы прокрастинируют меньше этого уровня, а 50% — больше.</li>
#     <li><strong>Сам "ящик":</strong> Он показывает диапазон, в котором находится "ядро" группы — средние 50% студентов.</li>
#     <li><strong>"Усы" (линии):</strong> Показывают почти весь разброс значений, исключая аномалии.</li>
# </ul>
#
# <h2>Какие выводы можно сделать?</h2>
# <p>
#     Сравнивая "ящики" между собой, мы можем сделать важные выводы:
# </p>
# <ul>
#     <li><strong>Сравнение медиан:</strong> Если медианная линия у одной группы расположена выше, чем у другой, это говорит о том, что "типичный" студент в этой группе прокрастинирует чаще.</li>
#     <li><strong>Сравнение размеров ящиков:</strong> Широкий "ящик" указывает на большой разброс мнений и неоднородность группы. Узкий ящик говорит о том, что большинство студентов в этой группе имеют схожий уровень прокрастинации.</li>
#     <li><strong>Общее расположение:</strong> Если один "ящик с усами" целиком расположен выше другого, это является сильным аргументом в пользу того, что в этой группе проблема прокрастинации стоит острее.</li>
# </ul>
# <p>
#     Эти графики позволяют нам перейти от общих цифр к поиску конкретных групп риска и проверке первых гипотез о факторах, влияющих на склонность к прокрастинации.
# </p>

# %%
plt.figure(figsize=(14, 7))

plt.subplot(1, 2, 1)
sns.boxplot(x='gender', y='procrastination_freq', data=df, palette='pastel')
plt.title('Частота прокрастинации в зависимости от пола')
plt.xlabel('Пол')
plt.ylabel('Частота прокрастинации (1-5)')

plt.subplot(1, 2, 2)
sns.boxplot(x='education_level', y='procrastination_freq', data=df, palette='pastel')
plt.title('Частота прокрастинации и уровень образования')
plt.xlabel('Уровень образования')
plt.ylabel('Частота прокрастинации (1-5)')
plt.xticks(rotation=15)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>Гипотеза 1: Различие в уровне прокрастинации между полами</h3>
# <p>Визуальный анализ мог показать небольшие различия в медианных значениях прокрастинации между мужчинами и женщинами. Проверим, является ли это различие статистически значимым.</p>
# <ul>
# <li><b>Нулевая гипотеза (H₀):</b> Средняя частота прокрастинации (<code>procrastination_freq</code>) одинакова для студентов мужского и женского пола.</li>
# <li><b>Альтернативная гипотеза (H₁):</b> Средняя частота прокрастинации статистически значимо различается между студентами мужского и женского пола.</li>
# </ul>
# <p><b>Метод проверки:</b> Независимый t-тест (Independent Samples t-test), так как мы сравниваем средние значения двух независимых групп.</p>
# <hr>

# %%
print("\n### Гипотеза 1: Различие в прокрастинации между полами ###")
male_scores = df[df['gender'] == 'Мужской']['procrastination_freq']
female_scores = df[df['gender'] == 'Женский']['procrastination_freq']

# Проводим t-тест для двух независимых выборок
t_stat, p_value_gender = stats.ttest_ind(male_scores, female_scores, equal_var=False) # equal_var=False (тест Уэлча) более устойчив

print(f"\nСредняя частота прокрастинации (мужчины): {male_scores.mean():.2f}")
print(f"Средняя частота прокрастинации (женщины): {female_scores.mean():.2f}")

print(f"\nt-статистика: {t_stat:.4f}")
print(f"p-value: {p_value_gender:.4f}")

if p_value_gender < 0.05:
    print("\nРезультат: p < 0.05. Отвергаем нулевую гипотезу. Существуют статистически значимые различия.\n")
else:
    print("\nРезультат: p >= 0.05. Не удалось отвергнуть нулевую гипотезу. Статистически значимых различий не обнаружено.\n")
# Out:
# ### Гипотеза 1: Различие в прокрастинации между полами ###
#
# Средняя частота прокрастинации (мужчины): 3.83
# Средняя частота прокрастинации (женщины): 3.83
#
# t-статистика: 0.0339
# p-value: 0.9730
#
# Результат: p >= 0.05. Не удалось отвергнуть нулевую гипотезу. Статистически значимых различий не обнаружено.

# %% [markdown]
# <h3>Гипотеза 2: Влияние уровня образования на прокрастинацию</h3>
# <p>Можно предположить, что студенты разных уровней образования (колледж, бакалавриат, магистратура) сталкиваются с разным уровнем академической нагрузки и стресса, что может влиять на частоту прокрастинации.</p>
# <ul>
# <li><b>Нулевая гипотеза (H₀):</b> Средняя частота прокрастинации не различается между студентами разных уровней образования.</li>
# <li><b>Альтернативная гипотеза (H₁):</b> Существует статистически значимое различие в средней частоте прокрастинации хотя бы между двумя из групп по уровню образования.</li>
# </ul>
# <p><b>Метод проверки:</b> Однофакторный дисперсионный анализ (ANOVA), так как мы сравниваем средние значения трех и более независимых групп.</p>
# <hr>

# %%
print("\n### Гипотеза 2: Влияние уровня образования на прокрастинацию ###")

education_levels = df['education_level'].unique()
grouped_data = [df['procrastination_freq'][df['education_level'] == level] for level in education_levels]

f_stat, p_value_edu = stats.f_oneway(*grouped_data)

print(f"\nУровни образования для сравнения: {list(education_levels)}\n")

print(f"F-статистика: {f_stat:.4f}")
print(f"p-value: {p_value_edu:.4f}")

if p_value_edu < 0.05:
    print("\nРезультат: p < 0.05. Отвергаем нулевую гипотезу. Существуют статистически значимые различия в частоте прокрастинации между группами.\n")
else:
    print("\nРезультат: p >= 0.05. Не удалось отвергнуть нулевую гипотезу. Различия между группами статистически не значимы.\n")
# Out:
# ### Гипотеза 2: Влияние уровня образования на прокрастинацию ###
#
# Уровни образования для сравнения: ['Бакалаврит/Специалитет', 'Магистратура', 'Колледж']
#
# F-статистика: 4.1444
# p-value: 0.0171
#
# Результат: p < 0.05. Отвергаем нулевую гипотезу. Существуют статистически значимые различия в частоте прокрастинации между группами.

# %% [markdown]
# <h3>Гипотеза 3: Связь между тревогой и прокрастинацией</h3>
# <p>Это одна из самых классических гипотез в психологии. Высокий уровень стресса и тревоги часто парализует и заставляет откладывать задачи.</p>
# <ul>
# <li><b>Нулевая гипотеза (H₀):</b> Отсутствует корреляция между уровнем тревожности/стресса (<code>anxiety_stress</code>) и частотой прокрастинации (<code>procrastination_freq</code>).</li>
# <li><b>Альтернативная гипотеза (H₁):</b> Существует статистически значимая положительная корреляция между уровнем тревожности/стресса и частотой прокрастинации.</li>
# </ul>
# <p><b>Метод проверки:</b> Ранговая корреляция Спирмена. Она подходит лучше, чем корреляция Пирсона, так как наши данные являются порядковыми (шкалы от 1 до 5) и их распределение может отличаться от нормального.</p>
# <hr>

# %%
print("\n### Гипотеза 3: Связь между тревогой и прокрастинацией ###")

corr_anxiety, p_value_anxiety = stats.spearmanr(df['procrastination_freq'], df['anxiety_stress'])

print(f"\nКоэффициент корреляции Спирмена: {corr_anxiety:.4f}")
print(f"p-value: {p_value_anxiety:.4f}")

if p_value_anxiety < 0.05:
    print("\nРезультат: p < 0.05. Отвергаем нулевую гипотезу. Обнаружена статистически значимая корреляция.\n")
    if corr_anxiety > 0:
        print("Тип связи: положительная. С ростом тревожности растет и частота прокрастинации.\n")
    else:
        print("Тип связи: отрицательная. С ростом тревожности частота прокрастинации снижается.\n")
else:
    print("\nРезультат: p >= 0.05. Не удалось отвергнуть нулевую гипотезу. Статистически значимой корреляции не обнаружено.\n")
# Out:
# ### Гипотеза 3: Связь между тревогой и прокрастинацией ###
#
# Коэффициент корреляции Спирмена: 0.2944
# p-value: 0.0000
#
# Результат: p < 0.05. Отвергаем нулевую гипотезу. Обнаружена статистически значимая корреляция.
#
# Тип связи: положительная. С ростом тревожности растет и частота прокрастинации.

# %% [markdown]
# <h3>Гипотеза 4: Связь между мотивацией и прокрастинацией</h3>
# <p>Обратная гипотеза: высокая внутренняя или внешняя мотивация должна снижать склонность к прокрастинации.</p>
# <ul>
# <li><b>Нулевая гипотеза (H₀):</b> Отсутствует корреляция между уровнем мотивации (<code>motivation</code>) и частотой прокрастинации (<code>procrastination_freq</code>).</li>
# <li><b>Альтернативная гипотеза (H₁):</b> Существует статистически значимая отрицательная корреляция между уровнем мотивации и частотой прокрастинации.</li>
# </ul>
# <p><b>Метод проверки:</b> Ранговая корреляция Спирмена.</p>

# %%
print("\n### Гипотеза 4: Связь между мотивацией и прокрастинацией ###")

corr_motivation, p_value_motivation = stats.spearmanr(df['procrastination_freq'], df['motivation'])

print(f"\nКоэффициент корреляции Спирмена: {corr_motivation:.4f}")
print(f"p-value: {p_value_motivation:.4f}")

if p_value_motivation < 0.05:
    print("\nРезультат: p < 0.05. Отвергаем нулевую гипотезу. Обнаружена статистически значимая корреляция.\n")
    if corr_motivation > 0:
        print("Тип связи: положительная. С ростом мотивации растет и частота прокрастинации.\n")
    else:
        print("Тип связи: отрицательная. С ростом мотивации частота прокрастинации снижается.\n")
else:
    print("\nРезультат: p >= 0.05. Не удалось отвергнуть нулевую гипотезу. Статистически значимой корреляции не обнаружено.\n")
# Out:
# ### Гипотеза 4: Связь между мотивацией и прокрастинацией ###
#
# Коэффициент корреляции Спирмена: -0.2193
# p-value: 0.0010
#
# Результат: p < 0.05. Отвергаем нулевую гипотезу. Обнаружена статистически значимая корреляция.
#
# Тип связи: отрицательная. С ростом мотивации частота прокрастинации снижается.

# %%
import networkx as nx
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error
import matplotlib.patches as mpatches
from adjustText import adjust_text
from sklearn.preprocessing import MinMaxScaler
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['font.family'] = 'DejaVu Sans'

# %%
class CognitiveMapModel:
    """
    Надежная модель когнитивной карты, использующая стабильные алгоритмы
    анализа центральности (Degree, Betweenness).
    """
    def __init__(self, concepts, corr_threshold=0.2, nonlinearity='tanh', k=0.5):
        self.concepts = concepts
        self.corr_threshold = corr_threshold
        self.nonlinearity = nonlinearity
        self.k = k
        self.graph = nx.DiGraph()
        self.node_metrics = {}
        self.is_built = False

    def _transfer_function(self, x):
        if self.nonlinearity == 'tanh':
            return (np.tanh(self.k * x) + 1) / 2
        elif self.nonlinearity == 'relu':
            val = np.maximum(0, x)
            return val / (val + 1)
        else:
            return 1 / (1 + np.exp(-self.k * x))

    def _scale_value(self, value, min_val=1, max_val=5):
        return value * (max_val - min_val) + min_val

    def build_from_data(self, data_df):
        print(f"Построение графа... Порог корреляции: {self.corr_threshold}, Нелинейность: {self.nonlinearity}")
        if not all(c in data_df.columns for c in self.concepts):
            missing = [c for c in self.concepts if c not in data_df.columns]
            raise ValueError(f"Концепты не найдены в DataFrame: {missing}")
        self.graph.add_nodes_from(self.concepts)
        corr_matrix = data_df[self.concepts].corr()
        for i in self.concepts:
            for j in self.concepts:
                if i == j: continue
                corr_value = corr_matrix.loc[i, j]
                if abs(corr_value) >= self.corr_threshold:
                    self.graph.add_edge(i, j, weight=corr_value)
        self.is_built = True
        self.analyze_graph()
        print(f"Граф построен. Вершин: {self.graph.number_of_nodes()}, Рёбер: {self.graph.number_of_edges()}")

    # --- ИЗМЕНЕННЫЙ И НАДЕЖНЫЙ МЕТОД АНАЛИЗА ---
    def analyze_graph(self):
        """
        Вычисляет ключевые метрики центральности с использованием
        стабильных алгоритмов.
        """
        if not self.is_built: return

        # Используем надежные метрики, которые не вызывают ошибок сходимости
        print("\nВычисление метрик центральности (Degree, Betweenness)...")
        self.node_metrics['degree'] = nx.degree_centrality(self.graph)
        self.node_metrics['betweenness'] = nx.betweenness_centrality(self.graph, weight='weight', normalized=True)

        print("\n--- Комплексный анализ центральности узлов ---")
        for metric_name, scores in self.node_metrics.items():
            print(f"\nТоп-5 узлов по метрике '{metric_name.capitalize()}':")
            sorted_nodes = sorted(scores.items(), key=lambda item: item[1], reverse=True)
            for node, score in sorted_nodes[:5]:
                print(f"  - {node}: {score:.3f}")

    def predict(self, initial_state, max_steps=30, stability_threshold=1e-5):
        if not self.is_built:
            raise RuntimeError("Модель не построена.")
        state = {k: (v - 1) / 4 for k, v in initial_state.items() if k in self.concepts}
        for _ in range(max_steps):
            next_state = state.copy()
            total_change = 0
            for node in self.graph.nodes():
                external_influence = sum(state.get(p, 0) * d['weight'] for p, _, d in self.graph.in_edges(node, data=True))
                input_signal = external_influence + state[node]
                new_value = self._transfer_function(input_signal)
                total_change += abs(new_value - state[node])
                next_state[node] = new_value
            state = next_state
            if total_change < stability_threshold: break
        return {k: self._scale_value(v) for k, v in state.items()}

    def run_scenario(self, interventions, base_profile=None):
        if base_profile is None:
            base_profile = {c: 3 for c in self.concepts}
        initial_state = base_profile.copy()
        base_pred = self.predict(initial_state)
        print(f"\n--- Моделирование сценария 'Что, если?' ---")
        print(f"Базовый уровень прокрастинации: {base_pred['procrastination_freq']:.2f}")
        modified_state = initial_state.copy()
        modified_state.update(interventions)
        print("Применены интервенции:")
        for k, v in interventions.items():
            print(f"  - {k} изменен на {v}")
        final_state = self.predict(modified_state)
        change = final_state['procrastination_freq'] - base_pred['procrastination_freq']
        print(f"Новый уровень прокрастинации: {final_state['procrastination_freq']:.2f} (Изменение: {change:+.2f})")
        return final_state

    # --- ИЗМЕНЕННЫЙ МЕТОД ВИЗУАЛИЗАЦИИ ---
    def visualize_graph(self, highlight_metric='degree'): # <-- Метрика по умолчанию теперь 'degree'
        """
        Визуализирует когнитивный граф. Размер узла определяется
        выбранной метрикой центральности (по умолчанию - Degree).
        """
        if not self.is_built:
            print("Граф не построен для визуализации.")
            return

        plt.figure(figsize=(24, 20))

        layout_g = nx.Graph()
        layout_g.add_nodes_from(self.graph.nodes())
        for u, v, data in self.graph.edges(data=True):
            distance = 1 - abs(data['weight'])
            layout_g.add_edge(u, v, weight=max(0.1, distance))
        pos = nx.kamada_kawai_layout(layout_g, weight='weight')

        # Размер узлов теперь по умолчанию зависит от Degree Centrality
        scores = self.node_metrics.get(highlight_metric, {})
        base_size = 1500
        # Коэффициент для Degree Centrality может быть больше
        size_multiplier = 20000
        node_sizes = [base_size + size_multiplier * scores.get(n, 0) for n in self.graph.nodes()]

        edge_weights = [d['weight'] for _, _, d in self.graph.edges(data=True)]
        edge_colors = ['#2b8cbe' if w > 0 else '#e41a1c' for w in edge_weights]

        nx.draw_networkx_nodes(self.graph, pos, node_color='#ff9900', node_size=node_sizes,
                               alpha=0.9, edgecolors='black', linewidths=1.0)
        nx.draw_networkx_edges(self.graph, pos, width=[abs(w) * 6 for w in edge_weights],
                               edge_color=edge_colors, alpha=0.6, arrowsize=25,
                               connectionstyle='arc3,rad=0.1')

        texts = []
        for node, (x, y) in pos.items():
            label = node.replace('_', ' ').capitalize()
            texts.append(plt.text(x, y, label, fontsize=14, fontweight='bold', ha='center', va='center', color='black'))

        adjust_text(texts, arrowprops=dict(arrowstyle="-", color='gray', lw=0.5))

        plt.title(f'Когнитивная карта (размер узла по метрике {highlight_metric.capitalize()})', fontsize=30, pad=20)
        pos_edge = mpatches.Patch(color='#2b8cbe', label='Положительное влияние')
        neg_edge = mpatches.Patch(color='#e41a1c', label='Отрицательное влияние')
        legend = plt.legend(handles=[pos_edge, neg_edge], fontsize=14, loc='upper right', frameon=True, facecolor='white', framealpha=0.9)
        legend.set_title("Тип влияния", prop={'size': 16, 'weight': 'bold'})
        plt.figtext(0.1, 0.05,
            f"Размер узла: пропорционален влиянию ({highlight_metric.capitalize()})\nТолщина ребра: пропорциональна силе связи (корреляции)",
            ha="left", fontsize=14, bbox={"facecolor":"white", "alpha":0.8, "pad":10})

        plt.axis('off')
        plt.tight_layout()
        plt.show()

    def evaluate(self, test_df, target_concept='procrastination_freq'):
        print("\n--- Оценка качества модели на тестовых данных ---")
        if not self.is_built:
            print("Модель не построена. Оценка невозможна.")
            return

        actual_values, predicted_values = [], []
        for _, row in test_df.iterrows():
            initial_state = row[self.concepts].to_dict()
            actual = initial_state.get(target_concept)
            predicted_full = self.predict(initial_state)
            predicted = predicted_full.get(target_concept)

            if actual is not None and predicted is not None:
                actual_values.append(actual)
                predicted_values.append(predicted)

        mae = mean_absolute_error(actual_values, predicted_values)
        r2 = r2_score(actual_values, predicted_values)

        print(f"Средняя абсолютная ошибка (MAE): {mae:.3f}")
        print(f"  -> Интерпретация: в среднем модель ошибается на {mae:.3f} балла по 5-балльной шкале.")
        print(f"Коэффициент детерминации (R²): {r2:.3f}")
        print(f"  -> Интерпретация: модель объясняет {r2*100:.1f}% вариативности целевой переменной.")

        plt.figure(figsize=(10, 8))
        plt.scatter(actual_values, predicted_values, alpha=0.7, edgecolors='k', s=80, label='Предсказания модели')
        plt.plot([min(actual_values), max(actual_values)], [min(actual_values), max(actual_values)], 'r--', lw=2, label='Идеальный прогноз')
        plt.xlabel('Реальные значения', fontsize=14)
        plt.ylabel('Предсказанные значения', fontsize=14)
        plt.title('Анализ ошибок: Предсказанные vs Реальные значения', fontsize=16)
        plt.grid(True)
        plt.legend()
        plt.axis('equal')
        plt.show()


# --- Использование доработанного класса ---

# 1. Определяем концепты для модели
concepts_to_model = [
    'procrastination_freq', 'procrastination_impact', 'anxiety_stress',
    'motivation', 'deadline_dependency', 'sleep_impact', 'social_media',
    'caffeine', 'environment', 'self_esteem', 'fatigue'
]

# 2. Разделяем данные на обучающую и тестовую выборки
train_df, test_df = train_test_split(df, test_size=0.25, random_state=42)

# 3. Создаем модель с пониженным порогом для большего числа связей
cognitive_model = CognitiveMapModel(
    concepts=concepts_to_model,
    corr_threshold=0.15, # Понижаем порог, чтобы добавить больше связей
    nonlinearity='tanh'
)
# Этот вызов теперь полностью безопасен
cognitive_model.build_from_data(train_df)

# 4. Визуализируем полученный граф. Размер узлов будет по 'degree'
cognitive_model.visualize_graph()

# При желании, можно посмотреть на граф с размерами по 'betweenness'
# cognitive_model.visualize_graph(highlight_metric='betweenness')

# 5. Оцениваем модель на данных, которые она не видела
cognitive_model.evaluate(test_df)

# 6. Запускаем сценарии "Что, если?"
cognitive_model.run_scenario(interventions={'fatigue': 1, 'motivation': 5})
# Out:
# Построение графа... Порог корреляции: 0.15, Нелинейность: tanh
#
# Вычисление метрик центральности (Degree, Betweenness)...
#
# --- Комплексный анализ центральности узлов ---
#
# Топ-5 узлов по метрике 'Degree':
#   - anxiety_stress: 1.000
#   - procrastination_freq: 0.800
#   - social_media: 0.800
#   - sleep_impact: 0.600
#   - procrastination_impact: 0.400
#
# Топ-5 узлов по метрике 'Betweenness':
#   - social_media: 0.678
#   - anxiety_stress: 0.644
#   - sleep_impact: 0.256
#   - procrastination_freq: 0.222
#   - environment: 0.200
# Граф построен. Вершин: 11, Рёбер: 28
# --- Оценка качества модели на тестовых данных ---
# Средняя абсолютная ошибка (MAE): 0.884
#   -> Интерпретация: в среднем модель ошибается на 0.884 балла по 5-балльной шкале.
# Коэффициент детерминации (R²): -0.067
#   -> Интерпретация: модель объясняет -6.7% вариативности целевой переменной.
# --- Моделирование сценария 'Что, если?' ---
# Базовый уровень прокрастинации: 4.16
# Применены интервенции:
#   - fatigue изменен на 1
#   - motivation изменен на 5
# Новый уровень прокрастинации: 4.16 (Изменение: -0.00)
# {'procrastination_freq': np.float64(4.156844146430442),
#  'procrastination_impact': np.float64(4.072140801048908),
#  'anxiety_stress': np.float64(4.121387935382798),
#  'motivation': np.float64(3.3401706028868317),
#  'deadline_dependency': np.float64(3.803954122881703),
#  'sleep_impact': np.float64(3.4087531995749516),
#  'social_media': np.float64(3.648729839600686),
#  'caffeine': np.float64(3.7067549125091106),
#  'environment': np.float64(3.9177274414155554),
#  'self_esteem': np.float64(3.611709026090479),
#  'fatigue': np.float64(4.0813240014771575)}

# %%
class CognitiveAutoencoder(nn.Module):
    def __init__(self, num_concepts, adjacency_mask):
        super().__init__()
        # Веса - это обучаемый линейный слой
        self.weights = nn.Linear(num_concepts, num_concepts, bias=False)

        # Маска определяет, какие веса могут быть ненулевыми
        self.register_buffer('adjacency_mask', torch.FloatTensor(adjacency_mask).T)

        # Применяем маску к весам при инициализации
        with torch.no_grad():
            self.weights.weight.mul_(self.adjacency_mask)

    def forward(self, x):
        # Применяем маску на каждом шаге, чтобы обнулить "запрещенные" градиенты
        self.weights.weight.data.mul_(self.adjacency_mask)
        return self.weights(x)

# --- ТРЕНЕР: Класс для управления обучением и анализом ---
class CognitiveMapTrainer:
    def __init__(self, concepts, lasso_alpha=0.05): # Сбалансированный alpha
        self.concepts = concepts
        self.concept_map = {name: i for i, name in enumerate(concepts)}
        self.lasso_alpha = lasso_alpha
        self.model = None
        self.scaler = MinMaxScaler() # Нормализатор данных
        self.is_trained = False

    def _build_adjacency_mask(self, data_df):
        print(f"Определение архитектуры сети с помощью Lasso (alpha={self.lasso_alpha})...")
        mask = np.zeros((len(self.concepts), len(self.concepts)))
        for i, target in enumerate(self.concepts):
            # Маскируем диагональ, чтобы узел не предсказывал сам себя
            np.fill_diagonal(mask, 0)

            y = data_df[target]
            X = data_df.drop(columns=[target])
            model = Lasso(alpha=self.lasso_alpha).fit(X, y)
            for j, feature in enumerate(X.columns):
                if abs(model.coef_[j]) > 0:
                    mask[i, self.concept_map[feature]] = 1

        num_connections = int(np.sum(mask))
        print(f"Архитектура определена. Найдено {num_connections} потенциальных связей.")
        if num_connections == 0:
            print("ПРЕДУПРЕЖДЕНИЕ: Не найдено ни одной связи. Модель не сможет обучаться. Попробуйте уменьшить lasso_alpha.")
        return mask

    def train(self, train_df, epochs=200, lr=0.01):
        print("\n--- Начало обучения модели ---")

        # 1. Нормализуем данные
        scaled_data = self.scaler.fit_transform(train_df)
        X_train = torch.FloatTensor(scaled_data)

        # 2. Строим архитектуру и модель
        adjacency_mask = self._build_adjacency_mask(train_df)
        self.model = CognitiveAutoencoder(len(self.concepts), adjacency_mask)

        train_dataset = TensorDataset(X_train, X_train)
        train_loader = DataLoader(train_dataset, batch_size=len(X_train), shuffle=True)

        optimizer = torch.optim.Adam(self.model.parameters(), lr=lr)
        criterion = nn.MSELoss()

        for epoch in range(epochs):
            for x_batch, y_batch in train_loader:
                optimizer.zero_grad()
                y_pred = self.model(x_batch) # Модель предсказывает y на основе x
                loss = criterion(y_pred, y_batch)
                loss.backward()
                optimizer.step()

            if (epoch + 1) % 20 == 0:
                print(f"Эпоха {epoch+1}/{epochs}, Потеря (Loss): {loss.item():.5f}")

        self.is_trained = True
        print("--- Обучение завершено ---")

    def _simulate_dynamics(self, initial_state, fixed_nodes=None, steps=10):
        """Приватный метод для симуляции динамики системы."""
        if fixed_nodes is None: fixed_nodes = {}

        # Нормализуем начальное состояние
        state_df = pd.DataFrame([initial_state])
        scaled_state = self.scaler.transform(state_df)

        # Применяем "зажатые" значения ПОСЛЕ нормализации
        for concept, value in fixed_nodes.items():
            # Нормализуем "зажатое" значение
            scaled_value = (value - self.scaler.min_[self.concept_map[concept]]) / self.scaler.scale_[self.concept_map[concept]]
            scaled_state[0, self.concept_map[concept]] = scaled_value

        state_tensor = torch.FloatTensor(scaled_state)

        self.model.eval()
        with torch.no_grad():
            for _ in range(steps):
                # Предсказываем следующее состояние на основе текущего
                next_state_pred = self.model(state_tensor)

                # Обновляем только не "зажатые" узлы
                for i in range(len(self.concepts)):
                    if self.concepts[i] not in fixed_nodes:
                        state_tensor[0, i] = next_state_pred[0, i]

        # Возвращаем результат в исходной шкале
        final_state_scaled = state_tensor.cpu().numpy()
        final_state_unscaled = self.scaler.inverse_transform(final_state_scaled)

        return dict(zip(self.concepts, final_state_unscaled[0]))

    def evaluate(self, test_df, target_concept='procrastination_freq'):
        if not self.is_trained: raise RuntimeError("Модель не обучена.")
        print("\n--- Оценка качества на тестовых данных ---")

        actuals = test_df[target_concept].values
        preds = []
        for _, row in test_df.iterrows():
            # Для оценки мы просто делаем одношаговое предсказание
            pred_state = self._simulate_dynamics(row.to_dict(), steps=1)
            preds.append(pred_state[target_concept])

        mae = mean_absolute_error(actuals, preds)
        r2 = r2_score(actuals, preds)

        print(f"Средняя абсолютная ошибка (MAE): {mae:.3f}")
        print(f"Коэффициент детерминации (R²): {r2:.3f}")
        if r2 > 0: print(f"  -> Модель объясняет {r2*100:.1f}% вариативности.")
        else: print(f"  -> Модель работает хуже простого среднего.")

    def run_scenario(self, interventions):
        if not self.is_trained: raise RuntimeError("Модель не обучена.")
        print("\n--- Моделирование сценария 'Что, если?' ---")

        base_profile = df[self.concepts].mean().to_dict()
        base_pred = self._simulate_dynamics(base_profile, steps=10)

        print(f"Базовый уровень прокрастинации: {base_pred['procrastination_freq']:.2f}")

        print("Применены интервенции (зафиксированы значения):")
        for k, v in interventions.items(): print(f"  - {k} = {v}")

        final_state = self._simulate_dynamics(base_profile, fixed_nodes=interventions, steps=10)

        change = final_state['procrastination_freq'] - base_pred['procrastination_freq']
        print(f"Новый уровень прокрастинации: {final_state['procrastination_freq']:.2f} (Изменение: {change:+.2f})")
        return final_state

    def visualize_graph(self):
        if not self.is_trained: raise RuntimeError("Модель не обучена.")
        print("\nВизуализация обученной когнитивной карты...")

        # Получаем обученные веса и строим граф
        weights = self.model.weights.weight.data.T.detach().cpu().numpy()
        G = nx.from_numpy_array(weights, create_using=nx.DiGraph)
        nx.relabel_nodes(G, {i: name for i, name in enumerate(self.concepts)}, copy=False)

        # Удаляем ребра с очень маленькими весами для чистоты
        edges_to_remove = [(u, v) for u, v, w in G.edges(data='weight') if abs(w) < 0.01]
        G.remove_edges_from(edges_to_remove)

        if G.number_of_edges() == 0:
            print("В графе нет значимых связей для визуализации.")
            return

        plt.figure(figsize=(24, 20))
        pos = nx.spring_layout(G, k=0.9, iterations=50, seed=42)

        edge_weights = [d['weight'] for _, _, d in G.edges(data=True)]
        edge_colors = ['#2b8cbe' if w > 0 else '#e41a1c' for w in edge_weights]

        nx.draw_networkx(G, pos, with_labels=False, node_color='#ff9900', node_size=3500,
                        width=[abs(w) * 10 for w in edge_weights], edge_color=edge_colors,
                        arrowsize=25, connectionstyle='arc3,rad=0.1')

        texts = [plt.text(x, y, node.replace('_', ' ').capitalize(), fontsize=14, fontweight='bold', ha='center', va='center', color='black') for node, (x, y) in pos.items()]
        adjust_text(texts, arrowprops=dict(arrowstyle="-", color='gray', lw=0.5))

        plt.title('Обученная когнитивная карта (модель автоэнкодера)', fontsize=30, pad=20)
        pos_edge = mpatches.Patch(color='#2b8cbe', label='Положительное влияние (усиливает)')
        neg_edge = mpatches.Patch(color='#e41a1c', label='Отрицательное влияние (ослабляет)')
        legend = plt.legend(handles=[pos_edge, neg_edge], fontsize=14, loc='upper right')
        plt.show()

# --- ИСПОЛЬЗОВАНИЕ КЛАССА ---

concepts_to_model = [
    'procrastination_freq', 'procrastination_impact', 'anxiety_stress',
    'motivation', 'deadline_dependency', 'sleep_impact', 'social_media',
    'caffeine', 'environment', 'self_esteem', 'fatigue'
]
train_df, test_df = train_test_split(df[concepts_to_model], test_size=0.25, random_state=42)

# Создаем "тренера" со сбалансированными настройками
trainer = CognitiveMapTrainer(concepts=concepts_to_model, lasso_alpha=0.05)

# Обучаем модель
trainer.train(train_df, epochs=10000, lr=0.001)

# Оцениваем качество
trainer.evaluate(test_df)

# Проводим сценарный анализ
trainer.run_scenario(interventions={'fatigue': 1, 'motivation': 5})

# Визуализируем финальную карту
trainer.visualize_graph()
# Out:
# --- Начало обучения модели ---
# Определение архитектуры сети с помощью Lasso (alpha=0.05)...
# Архитектура определена. Найдено 53 потенциальных связей.
# Эпоха 20/10000, Потеря (Loss): 0.58177
# Эпоха 40/10000, Потеря (Loss): 0.51381
# Эпоха 60/10000, Потеря (Loss): 0.45507
# Эпоха 80/10000, Потеря (Loss): 0.40460
# Эпоха 100/10000, Потеря (Loss): 0.36131
# Эпоха 120/10000, Потеря (Loss): 0.32432
# Эпоха 140/10000, Потеря (Loss): 0.29286
# Эпоха 160/10000, Потеря (Loss): 0.26622
# Эпоха 180/10000, Потеря (Loss): 0.24374
# Эпоха 200/10000, Потеря (Loss): 0.22480
# Эпоха 220/10000, Потеря (Loss): 0.20887
# Эпоха 240/10000, Потеря (Loss): 0.19545
# Эпоха 260/10000, Потеря (Loss): 0.18411
# Эпоха 280/10000, Потеря (Loss): 0.17450
# Эпоха 300/10000, Потеря (Loss): 0.16629
# Эпоха 320/10000, Потеря (Loss): 0.15925
# Эпоха 340/10000, Потеря (Loss): 0.15314
# Эпоха 360/10000, Потеря (Loss): 0.14781
# Эпоха 380/10000, Потеря (Loss): 0.14310
# Эпоха 400/10000, Потеря (Loss): 0.13890
# Эпоха 420/10000, Потеря (Loss): 0.13513
# Эпоха 440/10000, Потеря (Loss): 0.13171
# Эпоха 460/10000, Потеря (Loss): 0.12858
# Эпоха 480/10000, Потеря (Loss): 0.12570
# Эпоха 500/10000, Потеря (Loss): 0.12303
# Эпоха 520/10000, Потеря (Loss): 0.12054
# Эпоха 540/10000, Потеря (Loss): 0.11821
# Эпоха 560/10000, Потеря (Loss): 0.11601
# Эпоха 580/10000, Потеря (Loss): 0.11395
# Эпоха 600/10000, Потеря (Loss): 0.11200
# Эпоха 620/10000, Потеря (Loss): 0.11015
# Эпоха 640/10000, Потеря (Loss): 0.10840
# Эпоха 660/10000, Потеря (Loss): 0.10674
# Эпоха 680/10000, Потеря (Loss): 0.10516
# Эпоха 700/10000, Потеря (Loss): 0.10366
# Эпоха 720/10000, Потеря (Loss): 0.10224
# Эпоха 740/10000, Потеря (Loss): 0.10088
# Эпоха 760/10000, Потеря (Loss): 0.09960
# Эпоха 780/10000, Потеря (Loss): 0.09838
# Эпоха 800/10000, Потеря (Loss): 0.09722
# Эпоха 820/10000, Потеря (Loss): 0.09611
# Эпоха 840/10000, Потеря (Loss): 0.09507
# Эпоха 860/10000, Потеря (Loss): 0.09407
# Эпоха 880/10000, Потеря (Loss): 0.09312
# Эпоха 900/10000, Потеря (Loss): 0.09222
# Эпоха 920/10000, Потеря (Loss): 0.09137
# Эпоха 940/10000, Потеря (Loss): 0.09056
# Эпоха 960/10000, Потеря (Loss): 0.08978
# Эпоха 980/10000, Потеря (Loss): 0.08905
# Эпоха 1000/10000, Потеря (Loss): 0.08835
# Эпоха 1020/10000, Потеря (Loss): 0.08769
# Эпоха 1040/10000, Потеря (Loss): 0.08706
# Эпоха 1060/10000, Потеря (Loss): 0.08646
# Эпоха 1080/10000, Потеря (Loss): 0.08589
# Эпоха 1100/10000, Потеря (Loss): 0.08534
# Эпоха 1120/10000, Потеря (Loss): 0.08483
# Эпоха 1140/10000, Потеря (Loss): 0.08434
# Эпоха 1160/10000, Потеря (Loss): 0.08387
# Эпоха 1180/10000, Потеря (Loss): 0.08342
# Эпоха 1200/10000, Потеря (Loss): 0.08300
# Эпоха 1220/10000, Потеря (Loss): 0.08259
# Эпоха 1240/10000, Потеря (Loss): 0.08221
# Эпоха 1260/10000, Потеря (Loss): 0.08184
# Эпоха 1280/10000, Потеря (Loss): 0.08149
# Эпоха 1300/10000, Потеря (Loss): 0.08116
# Эпоха 1320/10000, Потеря (Loss): 0.08084
# Эпоха 1340/10000, Потеря (Loss): 0.08053
# Эпоха 1360/10000, Потеря (Loss): 0.08024
# Эпоха 1380/10000, Потеря (Loss): 0.07996
# Эпоха 1400/10000, Потеря (Loss): 0.07970
# Эпоха 1420/10000, Потеря (Loss): 0.07944
# Эпоха 1440/10000, Потеря (Loss): 0.07920
# Эпоха 1460/10000, Потеря (Loss): 0.07897
# Эпоха 1480/10000, Потеря (Loss): 0.07875
# Эпоха 1500/10000, Потеря (Loss): 0.07853
# Эпоха 1520/10000, Потеря (Loss): 0.07833
# Эпоха 1540/10000, Потеря (Loss): 0.07814
# Эпоха 1560/10000, Потеря (Loss): 0.07795
# Эпоха 1580/10000, Потеря (Loss): 0.07777
# Эпоха 1600/10000, Потеря (Loss): 0.07760
# Эпоха 1620/10000, Потеря (Loss): 0.07743
# Эпоха 1640/10000, Потеря (Loss): 0.07728
# Эпоха 1660/10000, Потеря (Loss): 0.07712
# Эпоха 1680/10000, Потеря (Loss): 0.07698
# Эпоха 1700/10000, Потеря (Loss): 0.07684
# Эпоха 1720/10000, Потеря (Loss): 0.07670
# Эпоха 1740/10000, Потеря (Loss): 0.07658
# Эпоха 1760/10000, Потеря (Loss): 0.07645
# Эпоха 1780/10000, Потеря (Loss): 0.07633
# Эпоха 1800/10000, Потеря (Loss): 0.07622
# Эпоха 1820/10000, Потеря (Loss): 0.07611
# Эпоха 1840/10000, Потеря (Loss): 0.07600
# Эпоха 1860/10000, Потеря (Loss): 0.07590
# Эпоха 1880/10000, Потеря (Loss): 0.07580
# Эпоха 1900/10000, Потеря (Loss): 0.07571
# Эпоха 1920/10000, Потеря (Loss): 0.07562
# Эпоха 1940/10000, Потеря (Loss): 0.07553
# Эпоха 1960/10000, Потеря (Loss): 0.07544
# Эпоха 1980/10000, Потеря (Loss): 0.07536
# Эпоха 2000/10000, Потеря (Loss): 0.07529
# Эпоха 2020/10000, Потеря (Loss): 0.07521
# Эпоха 2040/10000, Потеря (Loss): 0.07514
# Эпоха 2060/10000, Потеря (Loss): 0.07507
# Эпоха 2080/10000, Потеря (Loss): 0.07500
# Эпоха 2100/10000, Потеря (Loss): 0.07494
# Эпоха 2120/10000, Потеря (Loss): 0.07487
# Эпоха 2140/10000, Потеря (Loss): 0.07481
# Эпоха 2160/10000, Потеря (Loss): 0.07475
# Эпоха 2180/10000, Потеря (Loss): 0.07470
# Эпоха 2200/10000, Потеря (Loss): 0.07465
# Эпоха 2220/10000, Потеря (Loss): 0.07459
# Эпоха 2240/10000, Потеря (Loss): 0.07454
# Эпоха 2260/10000, Потеря (Loss): 0.07450
# Эпоха 2280/10000, Потеря (Loss): 0.07445
# Эпоха 2300/10000, Потеря (Loss): 0.07440
# Эпоха 2320/10000, Потеря (Loss): 0.07436
# Эпоха 2340/10000, Потеря (Loss): 0.07432
# Эпоха 2360/10000, Потеря (Loss): 0.07428
# Эпоха 2380/10000, Потеря (Loss): 0.07424
# Эпоха 2400/10000, Потеря (Loss): 0.07421
# Эпоха 2420/10000, Потеря (Loss): 0.07417
# Эпоха 2440/10000, Потеря (Loss): 0.07414
# Эпоха 2460/10000, Потеря (Loss): 0.07410
# Эпоха 2480/10000, Потеря (Loss): 0.07407
# Эпоха 2500/10000, Потеря (Loss): 0.07404
# Эпоха 2520/10000, Потеря (Loss): 0.07401
# Эпоха 2540/10000, Потеря (Loss): 0.07398
# Эпоха 2560/10000, Потеря (Loss): 0.07396
# Эпоха 2580/10000, Потеря (Loss): 0.07393
# Эпоха 2600/10000, Потеря (Loss): 0.07391
# Эпоха 2620/10000, Потеря (Loss): 0.07388
# Эпоха 2640/10000, Потеря (Loss): 0.07386
# Эпоха 2660/10000, Потеря (Loss): 0.07384
# Эпоха 2680/10000, Потеря (Loss): 0.07382
# Эпоха 2700/10000, Потеря (Loss): 0.07380
# Эпоха 2720/10000, Потеря (Loss): 0.07378
# Эпоха 2740/10000, Потеря (Loss): 0.07376
# Эпоха 2760/10000, Потеря (Loss): 0.07374
# Эпоха 2780/10000, Потеря (Loss): 0.07372
# Эпоха 2800/10000, Потеря (Loss): 0.07371
# Эпоха 2820/10000, Потеря (Loss): 0.07369
# Эпоха 2840/10000, Потеря (Loss): 0.07368
# Эпоха 2860/10000, Потеря (Loss): 0.07366
# Эпоха 2880/10000, Потеря (Loss): 0.07365
# Эпоха 2900/10000, Потеря (Loss): 0.07363
# Эпоха 2920/10000, Потеря (Loss): 0.07362
# Эпоха 2940/10000, Потеря (Loss): 0.07361
# Эпоха 2960/10000, Потеря (Loss): 0.07360
# Эпоха 2980/10000, Потеря (Loss): 0.07359
# Эпоха 3000/10000, Потеря (Loss): 0.07358
# Эпоха 3020/10000, Потеря (Loss): 0.07356
# Эпоха 3040/10000, Потеря (Loss): 0.07355
# Эпоха 3060/10000, Потеря (Loss): 0.07355
# Эпоха 3080/10000, Потеря (Loss): 0.07354
# Эпоха 3100/10000, Потеря (Loss): 0.07353
# Эпоха 3120/10000, Потеря (Loss): 0.07352
# Эпоха 3140/10000, Потеря (Loss): 0.07351
# Эпоха 3160/10000, Потеря (Loss): 0.07350
# Эпоха 3180/10000, Потеря (Loss): 0.07350
# Эпоха 3200/10000, Потеря (Loss): 0.07349
# Эпоха 3220/10000, Потеря (Loss): 0.07348
# Эпоха 3240/10000, Потеря (Loss): 0.07348
# Эпоха 3260/10000, Потеря (Loss): 0.07347
# Эпоха 3280/10000, Потеря (Loss): 0.07346
# Эпоха 3300/10000, Потеря (Loss): 0.07346
# Эпоха 3320/10000, Потеря (Loss): 0.07345
# Эпоха 3340/10000, Потеря (Loss): 0.07345
# Эпоха 3360/10000, Потеря (Loss): 0.07344
# Эпоха 3380/10000, Потеря (Loss): 0.07344
# Эпоха 3400/10000, Потеря (Loss): 0.07343
# Эпоха 3420/10000, Потеря (Loss): 0.07343
# Эпоха 3440/10000, Потеря (Loss): 0.07343
# Эпоха 3460/10000, Потеря (Loss): 0.07342
# Эпоха 3480/10000, Потеря (Loss): 0.07342
# Эпоха 3500/10000, Потеря (Loss): 0.07342
# Эпоха 3520/10000, Потеря (Loss): 0.07341
# Эпоха 3540/10000, Потеря (Loss): 0.07341
# Эпоха 3560/10000, Потеря (Loss): 0.07341
# Эпоха 3580/10000, Потеря (Loss): 0.07340
# Эпоха 3600/10000, Потеря (Loss): 0.07340
# Эпоха 3620/10000, Потеря (Loss): 0.07340
# Эпоха 3640/10000, Потеря (Loss): 0.07339
# Эпоха 3660/10000, Потеря (Loss): 0.07339
# Эпоха 3680/10000, Потеря (Loss): 0.07339
# Эпоха 3700/10000, Потеря (Loss): 0.07339
# Эпоха 3720/10000, Потеря (Loss): 0.07338
# Эпоха 3740/10000, Потеря (Loss): 0.07338
# Эпоха 3760/10000, Потеря (Loss): 0.07338
# Эпоха 3780/10000, Потеря (Loss): 0.07338
# Эпоха 3800/10000, Потеря (Loss): 0.07338
# Эпоха 3820/10000, Потеря (Loss): 0.07337
# Эпоха 3840/10000, Потеря (Loss): 0.07337
# Эпоха 3860/10000, Потеря (Loss): 0.07337
# Эпоха 3880/10000, Потеря (Loss): 0.07337
# Эпоха 3900/10000, Потеря (Loss): 0.07337
# Эпоха 3920/10000, Потеря (Loss): 0.07337
# Эпоха 3940/10000, Потеря (Loss): 0.07337
# Эпоха 3960/10000, Потеря (Loss): 0.07336
# Эпоха 3980/10000, Потеря (Loss): 0.07336
# Эпоха 4000/10000, Потеря (Loss): 0.07336
# Эпоха 4020/10000, Потеря (Loss): 0.07336
# Эпоха 4040/10000, Потеря (Loss): 0.07336
# Эпоха 4060/10000, Потеря (Loss): 0.07336
# Эпоха 4080/10000, Потеря (Loss): 0.07336
# Эпоха 4100/10000, Потеря (Loss): 0.07336
# Эпоха 4120/10000, Потеря (Loss): 0.07336
# Эпоха 4140/10000, Потеря (Loss): 0.07335
# Эпоха 4160/10000, Потеря (Loss): 0.07335
# Эпоха 4180/10000, Потеря (Loss): 0.07335
# Эпоха 4200/10000, Потеря (Loss): 0.07335
# Эпоха 4220/10000, Потеря (Loss): 0.07335
# Эпоха 4240/10000, Потеря (Loss): 0.07335
# Эпоха 4260/10000, Потеря (Loss): 0.07335
# Эпоха 4280/10000, Потеря (Loss): 0.07335
# Эпоха 4300/10000, Потеря (Loss): 0.07335
# Эпоха 4320/10000, Потеря (Loss): 0.07335
# Эпоха 4340/10000, Потеря (Loss): 0.07335
# Эпоха 4360/10000, Потеря (Loss): 0.07335
# Эпоха 4380/10000, Потеря (Loss): 0.07335
# Эпоха 4400/10000, Потеря (Loss): 0.07334
# Эпоха 4420/10000, Потеря (Loss): 0.07334
# Эпоха 4440/10000, Потеря (Loss): 0.07334
# Эпоха 4460/10000, Потеря (Loss): 0.07334
# Эпоха 4480/10000, Потеря (Loss): 0.07334
# Эпоха 4500/10000, Потеря (Loss): 0.07334
# Эпоха 4520/10000, Потеря (Loss): 0.07334
# Эпоха 4540/10000, Потеря (Loss): 0.07334
# Эпоха 4560/10000, Потеря (Loss): 0.07334
# Эпоха 4580/10000, Потеря (Loss): 0.07334
# Эпоха 4600/10000, Потеря (Loss): 0.07334
# Эпоха 4620/10000, Потеря (Loss): 0.07334
# Эпоха 4640/10000, Потеря (Loss): 0.07334
# Эпоха 4660/10000, Потеря (Loss): 0.07334
# Эпоха 4680/10000, Потеря (Loss): 0.07334
# Эпоха 4700/10000, Потеря (Loss): 0.07334
# Эпоха 4720/10000, Потеря (Loss): 0.07334
# Эпоха 4740/10000, Потеря (Loss): 0.07334
# Эпоха 4760/10000, Потеря (Loss): 0.07334
# Эпоха 4780/10000, Потеря (Loss): 0.07334
# Эпоха 4800/10000, Потеря (Loss): 0.07334
# Эпоха 4820/10000, Потеря (Loss): 0.07334
# Эпоха 4840/10000, Потеря (Loss): 0.07334
# Эпоха 4860/10000, Потеря (Loss): 0.07334
# Эпоха 4880/10000, Потеря (Loss): 0.07334
# Эпоха 4900/10000, Потеря (Loss): 0.07334
# Эпоха 4920/10000, Потеря (Loss): 0.07334
# Эпоха 4940/10000, Потеря (Loss): 0.07334
# Эпоха 4960/10000, Потеря (Loss): 0.07334
# Эпоха 4980/10000, Потеря (Loss): 0.07333
# Эпоха 5000/10000, Потеря (Loss): 0.07333
# Эпоха 5020/10000, Потеря (Loss): 0.07333
# Эпоха 5040/10000, Потеря (Loss): 0.07333
# Эпоха 5060/10000, Потеря (Loss): 0.07333
# Эпоха 5080/10000, Потеря (Loss): 0.07333
# Эпоха 5100/10000, Потеря (Loss): 0.07333
# Эпоха 5120/10000, Потеря (Loss): 0.07333
# Эпоха 5140/10000, Потеря (Loss): 0.07333
# Эпоха 5160/10000, Потеря (Loss): 0.07333
# Эпоха 5180/10000, Потеря (Loss): 0.07333
# Эпоха 5200/10000, Потеря (Loss): 0.07333
# Эпоха 5220/10000, Потеря (Loss): 0.07333
# Эпоха 5240/10000, Потеря (Loss): 0.07333
# Эпоха 5260/10000, Потеря (Loss): 0.07333
# Эпоха 5280/10000, Потеря (Loss): 0.07333
# Эпоха 5300/10000, Потеря (Loss): 0.07333
# Эпоха 5320/10000, Потеря (Loss): 0.07333
# Эпоха 5340/10000, Потеря (Loss): 0.07333
# Эпоха 5360/10000, Потеря (Loss): 0.07333
# Эпоха 5380/10000, Потеря (Loss): 0.07333
# Эпоха 5400/10000, Потеря (Loss): 0.07333
# Эпоха 5420/10000, Потеря (Loss): 0.07333
# Эпоха 5440/10000, Потеря (Loss): 0.07333
# Эпоха 5460/10000, Потеря (Loss): 0.07333
# Эпоха 5480/10000, Потеря (Loss): 0.07333
# Эпоха 5500/10000, Потеря (Loss): 0.07333
# Эпоха 5520/10000, Потеря (Loss): 0.07333
# Эпоха 5540/10000, Потеря (Loss): 0.07333
# Эпоха 5560/10000, Потеря (Loss): 0.07333
# Эпоха 5580/10000, Потеря (Loss): 0.07333
# Эпоха 5600/10000, Потеря (Loss): 0.07333
# Эпоха 5620/10000, Потеря (Loss): 0.07333
# Эпоха 5640/10000, Потеря (Loss): 0.07333
# Эпоха 5660/10000, Потеря (Loss): 0.07333
# Эпоха 5680/10000, Потеря (Loss): 0.07333
# Эпоха 5700/10000, Потеря (Loss): 0.07333
# Эпоха 5720/10000, Потеря (Loss): 0.07333
# Эпоха 5740/10000, Потеря (Loss): 0.07333
# Эпоха 5760/10000, Потеря (Loss): 0.07333
# Эпоха 5780/10000, Потеря (Loss): 0.07333
# Эпоха 5800/10000, Потеря (Loss): 0.07333
# Эпоха 5820/10000, Потеря (Loss): 0.07333
# Эпоха 5840/10000, Потеря (Loss): 0.07333
# Эпоха 5860/10000, Потеря (Loss): 0.07333
# Эпоха 5880/10000, Потеря (Loss): 0.07333
# Эпоха 5900/10000, Потеря (Loss): 0.07333
# Эпоха 5920/10000, Потеря (Loss): 0.07333
# Эпоха 5940/10000, Потеря (Loss): 0.07333
# Эпоха 5960/10000, Потеря (Loss): 0.07333
# Эпоха 5980/10000, Потеря (Loss): 0.07333
# Эпоха 6000/10000, Потеря (Loss): 0.07333
# Эпоха 6020/10000, Потеря (Loss): 0.07333
# Эпоха 6040/10000, Потеря (Loss): 0.07333
# Эпоха 6060/10000, Потеря (Loss): 0.07333
# Эпоха 6080/10000, Потеря (Loss): 0.07333
# Эпоха 6100/10000, Потеря (Loss): 0.07333
# Эпоха 6120/10000, Потеря (Loss): 0.07333
# Эпоха 6140/10000, Потеря (Loss): 0.07333
# Эпоха 6160/10000, Потеря (Loss): 0.07333
# Эпоха 6180/10000, Потеря (Loss): 0.07333
# Эпоха 6200/10000, Потеря (Loss): 0.07333
# Эпоха 6220/10000, Потеря (Loss): 0.07333
# Эпоха 6240/10000, Потеря (Loss): 0.07333
# Эпоха 6260/10000, Потеря (Loss): 0.07333
# Эпоха 6280/10000, Потеря (Loss): 0.07333
# Эпоха 6300/10000, Потеря (Loss): 0.07333
# Эпоха 6320/10000, Потеря (Loss): 0.07333
# Эпоха 6340/10000, Потеря (Loss): 0.07333
# Эпоха 6360/10000, Потеря (Loss): 0.07333
# Эпоха 6380/10000, Потеря (Loss): 0.07333
# Эпоха 6400/10000, Потеря (Loss): 0.07333
# Эпоха 6420/10000, Потеря (Loss): 0.07333
# Эпоха 6440/10000, Потеря (Loss): 0.07333
# Эпоха 6460/10000, Потеря (Loss): 0.07333
# Эпоха 6480/10000, Потеря (Loss): 0.07333
# Эпоха 6500/10000, Потеря (Loss): 0.07333
# Эпоха 6520/10000, Потеря (Loss): 0.07333
# Эпоха 6540/10000, Потеря (Loss): 0.07333
# Эпоха 6560/10000, Потеря (Loss): 0.07333
# Эпоха 6580/10000, Потеря (Loss): 0.07333
# Эпоха 6600/10000, Потеря (Loss): 0.07333
# Эпоха 6620/10000, Потеря (Loss): 0.07333
# Эпоха 6640/10000, Потеря (Loss): 0.07333
# Эпоха 6660/10000, Потеря (Loss): 0.07333
# Эпоха 6680/10000, Потеря (Loss): 0.07333
# Эпоха 6700/10000, Потеря (Loss): 0.07333
# Эпоха 6720/10000, Потеря (Loss): 0.07333
# Эпоха 6740/10000, Потеря (Loss): 0.07333
# Эпоха 6760/10000, Потеря (Loss): 0.07333
# Эпоха 6780/10000, Потеря (Loss): 0.07333
# Эпоха 6800/10000, Потеря (Loss): 0.07333
# Эпоха 6820/10000, Потеря (Loss): 0.07333
# Эпоха 6840/10000, Потеря (Loss): 0.07333
# Эпоха 6860/10000, Потеря (Loss): 0.07333
# Эпоха 6880/10000, Потеря (Loss): 0.07333
# Эпоха 6900/10000, Потеря (Loss): 0.07333
# Эпоха 6920/10000, Потеря (Loss): 0.07333
# Эпоха 6940/10000, Потеря (Loss): 0.07333
# Эпоха 6960/10000, Потеря (Loss): 0.07333
# Эпоха 6980/10000, Потеря (Loss): 0.07333
# Эпоха 7000/10000, Потеря (Loss): 0.07333
# Эпоха 7020/10000, Потеря (Loss): 0.07333
# Эпоха 7040/10000, Потеря (Loss): 0.07333
# Эпоха 7060/10000, Потеря (Loss): 0.07333
# Эпоха 7080/10000, Потеря (Loss): 0.07333
# Эпоха 7100/10000, Потеря (Loss): 0.07333
# Эпоха 7120/10000, Потеря (Loss): 0.07333
# Эпоха 7140/10000, Потеря (Loss): 0.07333
# Эпоха 7160/10000, Потеря (Loss): 0.07333
# Эпоха 7180/10000, Потеря (Loss): 0.07333
# Эпоха 7200/10000, Потеря (Loss): 0.07333
# Эпоха 7220/10000, Потеря (Loss): 0.07333
# Эпоха 7240/10000, Потеря (Loss): 0.07333
# Эпоха 7260/10000, Потеря (Loss): 0.07333
# Эпоха 7280/10000, Потеря (Loss): 0.07333
# Эпоха 7300/10000, Потеря (Loss): 0.07333
# Эпоха 7320/10000, Потеря (Loss): 0.07333
# Эпоха 7340/10000, Потеря (Loss): 0.07333
# Эпоха 7360/10000, Потеря (Loss): 0.07333
# Эпоха 7380/10000, Потеря (Loss): 0.07333
# Эпоха 7400/10000, Потеря (Loss): 0.07333
# Эпоха 7420/10000, Потеря (Loss): 0.07333
# Эпоха 7440/10000, Потеря (Loss): 0.07333
# Эпоха 7460/10000, Потеря (Loss): 0.07333
# Эпоха 7480/10000, Потеря (Loss): 0.07333
# Эпоха 7500/10000, Потеря (Loss): 0.07333
# Эпоха 7520/10000, Потеря (Loss): 0.07333
# Эпоха 7540/10000, Потеря (Loss): 0.07333
# Эпоха 7560/10000, Потеря (Loss): 0.07333
# Эпоха 7580/10000, Потеря (Loss): 0.07333
# Эпоха 7600/10000, Потеря (Loss): 0.07333
# Эпоха 7620/10000, Потеря (Loss): 0.07333
# Эпоха 7640/10000, Потеря (Loss): 0.07333
# Эпоха 7660/10000, Потеря (Loss): 0.07333
# Эпоха 7680/10000, Потеря (Loss): 0.07333
# Эпоха 7700/10000, Потеря (Loss): 0.07333
# Эпоха 7720/10000, Потеря (Loss): 0.07333
# Эпоха 7740/10000, Потеря (Loss): 0.07333
# Эпоха 7760/10000, Потеря (Loss): 0.07333
# Эпоха 7780/10000, Потеря (Loss): 0.07333
# Эпоха 7800/10000, Потеря (Loss): 0.07333
# Эпоха 7820/10000, Потеря (Loss): 0.07333
# Эпоха 7840/10000, Потеря (Loss): 0.07333
# Эпоха 7860/10000, Потеря (Loss): 0.07333
# Эпоха 7880/10000, Потеря (Loss): 0.07333
# Эпоха 7900/10000, Потеря (Loss): 0.07333
# Эпоха 7920/10000, Потеря (Loss): 0.07333
# Эпоха 7940/10000, Потеря (Loss): 0.07333
# Эпоха 7960/10000, Потеря (Loss): 0.07333
# Эпоха 7980/10000, Потеря (Loss): 0.07333
# Эпоха 8000/10000, Потеря (Loss): 0.07333
# Эпоха 8020/10000, Потеря (Loss): 0.07333
# Эпоха 8040/10000, Потеря (Loss): 0.07333
# Эпоха 8060/10000, Потеря (Loss): 0.07333
# Эпоха 8080/10000, Потеря (Loss): 0.07333
# Эпоха 8100/10000, Потеря (Loss): 0.07333
# Эпоха 8120/10000, Потеря (Loss): 0.07333
# Эпоха 8140/10000, Потеря (Loss): 0.07333
# Эпоха 8160/10000, Потеря (Loss): 0.07333
# Эпоха 8180/10000, Потеря (Loss): 0.07333
# Эпоха 8200/10000, Потеря (Loss): 0.07333
# Эпоха 8220/10000, Потеря (Loss): 0.07333
# Эпоха 8240/10000, Потеря (Loss): 0.07333
# Эпоха 8260/10000, Потеря (Loss): 0.07333
# Эпоха 8280/10000, Потеря (Loss): 0.07333
# Эпоха 8300/10000, Потеря (Loss): 0.07333
# Эпоха 8320/10000, Потеря (Loss): 0.07333
# Эпоха 8340/10000, Потеря (Loss): 0.07333
# Эпоха 8360/10000, Потеря (Loss): 0.07333
# Эпоха 8380/10000, Потеря (Loss): 0.07333
# Эпоха 8400/10000, Потеря (Loss): 0.07333
# Эпоха 8420/10000, Потеря (Loss): 0.07333
# Эпоха 8440/10000, Потеря (Loss): 0.07333
# Эпоха 8460/10000, Потеря (Loss): 0.07333
# Эпоха 8480/10000, Потеря (Loss): 0.07333
# Эпоха 8500/10000, Потеря (Loss): 0.07333
# Эпоха 8520/10000, Потеря (Loss): 0.07333
# Эпоха 8540/10000, Потеря (Loss): 0.07333
# Эпоха 8560/10000, Потеря (Loss): 0.07333
# Эпоха 8580/10000, Потеря (Loss): 0.07333
# Эпоха 8600/10000, Потеря (Loss): 0.07333
# Эпоха 8620/10000, Потеря (Loss): 0.07333
# Эпоха 8640/10000, Потеря (Loss): 0.07333
# Эпоха 8660/10000, Потеря (Loss): 0.07333
# Эпоха 8680/10000, Потеря (Loss): 0.07333
# Эпоха 8700/10000, Потеря (Loss): 0.07333
# Эпоха 8720/10000, Потеря (Loss): 0.07333
# Эпоха 8740/10000, Потеря (Loss): 0.07333
# Эпоха 8760/10000, Потеря (Loss): 0.07333
# Эпоха 8780/10000, Потеря (Loss): 0.07333
# Эпоха 8800/10000, Потеря (Loss): 0.07333
# Эпоха 8820/10000, Потеря (Loss): 0.07333
# Эпоха 8840/10000, Потеря (Loss): 0.07333
# Эпоха 8860/10000, Потеря (Loss): 0.07333
# Эпоха 8880/10000, Потеря (Loss): 0.07333
# Эпоха 8900/10000, Потеря (Loss): 0.07333
# Эпоха 8920/10000, Потеря (Loss): 0.07333
# Эпоха 8940/10000, Потеря (Loss): 0.07333
# Эпоха 8960/10000, Потеря (Loss): 0.07333
# Эпоха 8980/10000, Потеря (Loss): 0.07333
# Эпоха 9000/10000, Потеря (Loss): 0.07333
# Эпоха 9020/10000, Потеря (Loss): 0.07333
# Эпоха 9040/10000, Потеря (Loss): 0.07333
# Эпоха 9060/10000, Потеря (Loss): 0.07333
# Эпоха 9080/10000, Потеря (Loss): 0.07333
# Эпоха 9100/10000, Потеря (Loss): 0.07333
# Эпоха 9120/10000, Потеря (Loss): 0.07333
# Эпоха 9140/10000, Потеря (Loss): 0.07333
# Эпоха 9160/10000, Потеря (Loss): 0.07333
# Эпоха 9180/10000, Потеря (Loss): 0.07333
# Эпоха 9200/10000, Потеря (Loss): 0.07333
# Эпоха 9220/10000, Потеря (Loss): 0.07333
# Эпоха 9240/10000, Потеря (Loss): 0.07333
# Эпоха 9260/10000, Потеря (Loss): 0.07333
# Эпоха 9280/10000, Потеря (Loss): 0.07333
# Эпоха 9300/10000, Потеря (Loss): 0.07333
# Эпоха 9320/10000, Потеря (Loss): 0.07333
# Эпоха 9340/10000, Потеря (Loss): 0.07333
# Эпоха 9360/10000, Потеря (Loss): 0.07333
# Эпоха 9380/10000, Потеря (Loss): 0.07333
# Эпоха 9400/10000, Потеря (Loss): 0.07333
# Эпоха 9420/10000, Потеря (Loss): 0.07333
# Эпоха 9440/10000, Потеря (Loss): 0.07333
# Эпоха 9460/10000, Потеря (Loss): 0.07333
# Эпоха 9480/10000, Потеря (Loss): 0.07333
# Эпоха 9500/10000, Потеря (Loss): 0.07333
# Эпоха 9520/10000, Потеря (Loss): 0.07333
# Эпоха 9540/10000, Потеря (Loss): 0.07333
# Эпоха 9560/10000, Потеря (Loss): 0.07333
# Эпоха 9580/10000, Потеря (Loss): 0.07333
# Эпоха 9600/10000, Потеря (Loss): 0.07333
# Эпоха 9620/10000, Потеря (Loss): 0.07333
# Эпоха 9640/10000, Потеря (Loss): 0.07333
# Эпоха 9660/10000, Потеря (Loss): 0.07333
# Эпоха 9680/10000, Потеря (Loss): 0.07333
# Эпоха 9700/10000, Потеря (Loss): 0.07333
# Эпоха 9720/10000, Потеря (Loss): 0.07333
# Эпоха 9740/10000, Потеря (Loss): 0.07333
# Эпоха 9760/10000, Потеря (Loss): 0.07333
# Эпоха 9780/10000, Потеря (Loss): 0.07333
# Эпоха 9800/10000, Потеря (Loss): 0.07333
# Эпоха 9820/10000, Потеря (Loss): 0.07333
# Эпоха 9840/10000, Потеря (Loss): 0.07333
# Эпоха 9860/10000, Потеря (Loss): 0.07333
# Эпоха 9880/10000, Потеря (Loss): 0.07333
# Эпоха 9900/10000, Потеря (Loss): 0.07333
# Эпоха 9920/10000, Потеря (Loss): 0.07333
# Эпоха 9940/10000, Потеря (Loss): 0.07333
# Эпоха 9960/10000, Потеря (Loss): 0.07333
# Эпоха 9980/10000, Потеря (Loss): 0.07333
# Эпоха 10000/10000, Потеря (Loss): 0.07333
# --- Обучение завершено ---
#
# --- Оценка качества на тестовых данных ---
# Средняя абсолютная ошибка (MAE): 0.813
# Коэффициент детерминации (R²): 0.097
#   -> Модель объясняет 9.7% вариативности.
#
# --- Моделирование сценария 'Что, если?' ---
# Базовый уровень прокрастинации: 3.19
# Применены интервенции (зафиксированы значения):
#   - fatigue = 1
#   - motivation = 5
# Новый уровень прокрастинации: 0.39 (Изменение: -2.80)
#
# Визуализация обученной когнитивной карты...

# %%
class CognitiveAutoencoder(nn.Module):
    def __init__(self, num_concepts, hidden_size=6):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Linear(num_concepts, hidden_size),
            nn.ReLU()
        )
        self.decoder = nn.Linear(hidden_size, num_concepts)

    def forward(self, x):
        hidden = self.encoder(x)
        reconstructed = self.decoder(hidden)
        return reconstructed

# --- ТРЕНЕР: Класс для управления обучением и анализом ---
class CognitiveMapTrainer:
    def __init__(self, concepts):
        self.concepts = concepts
        self.concept_map = {name: i for i, name in enumerate(concepts)}
        self.model = None
        self.scaler = MinMaxScaler()
        self.is_trained = False

    def train(self, train_df, epochs=300, lr=0.005, weight_decay=1e-4):
        print("\n--- Начало обучения нелинейной модели ---")

        scaled_data = self.scaler.fit_transform(train_df)
        X_train = torch.FloatTensor(scaled_data)

        self.model = CognitiveAutoencoder(len(self.concepts))

        train_dataset = TensorDataset(X_train, X_train)
        train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

        optimizer = torch.optim.Adam(self.model.parameters(), lr=lr, weight_decay=weight_decay)
        criterion = nn.MSELoss()

        for epoch in range(epochs):
            for x_batch, y_batch in train_loader:
                optimizer.zero_grad()
                y_pred = self.model(x_batch)
                loss = criterion(y_pred, y_batch)
                loss.backward()
                optimizer.step()

            if (epoch + 1) % 50 == 0:
                print(f"Эпоха {epoch+1}/{epochs}, Потеря (Loss): {loss.item():.6f}")

        self.is_trained = True
        print("--- Обучение завершено ---")

    def _simulate_dynamics(self, initial_state, fixed_nodes=None, steps=10):
        """Приватный метод для симуляции динамики системы с ограничением значений."""
        if fixed_nodes is None: fixed_nodes = {}

        state_df = pd.DataFrame([initial_state], columns=self.concepts)
        scaled_state = self.scaler.transform(state_df)

        for concept, value in fixed_nodes.items():
            idx = self.concept_map[concept]
            # Нормализуем и "зажимаем" значение в [0, 1], чтобы избежать выхода за пределы при нормализации
            scaled_value = np.clip((value - self.scaler.min_[idx]) / self.scaler.scale_[idx], 0, 1)
            scaled_state[0, idx] = scaled_value

        state_tensor = torch.FloatTensor(scaled_state)

        self.model.eval()
        with torch.no_grad():
            for _ in range(steps):
                next_state_pred = self.model(state_tensor)
                for i in range(len(self.concepts)):
                    if self.concepts[i] not in fixed_nodes:
                        state_tensor[0, i] = next_state_pred[0, i]

                # --- КЛЮЧЕВОЕ ИСПРАВЛЕНИЕ ---
                # Ограничиваем состояние в допустимом нормализованном диапазоне [0, 1]
                # Это предотвращает "взрыв" симуляции.
                state_tensor.clamp_(0, 1)

        final_state_unscaled = self.scaler.inverse_transform(state_tensor.cpu().numpy())
        return dict(zip(self.concepts, final_state_unscaled[0]))

    # --- ИСПРАВЛЕННЫЙ МЕТОД ОЦЕНКИ ---
    def evaluate(self, test_df, target_concept='procrastination_freq'):
        if not self.is_trained: raise RuntimeError("Модель не обучена.")
        print("\n--- Оценка качества на тестовых данных ---")

        actuals = test_df[target_concept].values
        preds = []
        for _, row in test_df.iterrows():
            pred_state = self._simulate_dynamics(row.to_dict(), steps=1)
            preds.append(pred_state[target_concept])

        # Вычисляем MSE
        mse = mean_squared_error(actuals, preds)
        # Вычисляем RMSE как квадратный корень из MSE (универсальный способ)
        rmse = np.sqrt(mse)
        r2 = r2_score(actuals, preds)

        print(f"Среднеквадратичная ошибка (RMSE): {rmse:.3f}")
        print(f"Коэффициент детерминации (R²): {r2:.3f}")
        if r2 > 0: print(f"  -> Модель объясняет {r2*100:.1f}% вариативности.")
        else: print(f"  -> Модель работает хуже простого среднего.")

    def run_scenario(self, interventions):
        if not self.is_trained: raise RuntimeError("Модель не обучена.")
        print("\n--- Моделирование сценария 'Что, если?' ---")

        base_profile = df[self.concepts].mean().to_dict()
        base_pred = self._simulate_dynamics(base_profile, steps=10)

        print(f"Базовый уровень прокрастинации: {base_pred['procrastination_freq']:.2f}")

        print("Применены интервенции (зафиксированы значения):")
        for k, v in interventions.items(): print(f"  - {k} = {v}")

        final_state = self._simulate_dynamics(base_profile, fixed_nodes=interventions, steps=10)

        change = final_state['procrastination_freq'] - base_pred['procrastination_freq']
        print(f"Новый уровень прокрастинации: {final_state['procrastination_freq']:.2f} (Изменение: {change:+.2f})")
        return final_state

    def visualize_graph(self):
        if not self.is_trained: raise RuntimeError("Модель не обучена.")
        print("\nВизуализация обученной карты влияния...")

        mean_input = torch.FloatTensor(self.scaler.transform(df[self.concepts].mean().values.reshape(1, -1)))
        jacobian = torch.autograd.functional.jacobian(self.model, mean_input)

        influence_matrix = jacobian.squeeze().detach().cpu().numpy()

        G = nx.from_numpy_array(influence_matrix, create_using=nx.DiGraph)
        nx.relabel_nodes(G, {i: name for i, name in enumerate(self.concepts)}, copy=False)

        edges_to_remove = [(u, v) for u, v, w in G.edges(data='weight') if abs(w) < 0.05]
        G.remove_edges_from(edges_to_remove)

        if G.number_of_edges() == 0:
            print("В графе нет значимых связей для визуализации.")
            return

        plt.figure(figsize=(24, 20))
        pos = nx.spring_layout(G, k=1.2, iterations=100, seed=42)

        edge_weights = [d['weight'] for _, _, d in G.edges(data=True)]
        edge_colors = ['#2b8cbe' if w > 0 else '#e41a1c' for w in edge_weights]

        nx.draw_networkx(G, pos, with_labels=False, node_color='#ff9900', node_size=4000,
                        width=[abs(w) * 15 for w in edge_weights], edge_color=edge_colors,
                        arrowsize=30, connectionstyle='arc3,rad=0.1')

        texts = [plt.text(x, y, node.replace('_', ' ').capitalize(), fontsize=16, fontweight='bold', ha='center', va='center', color='black') for node, (x, y) in pos.items()]
        adjust_text(texts, arrowprops=dict(arrowstyle="-", color='gray', lw=0.5))

        plt.title('Карта влияния (нелинейная нейросетевая модель)', fontsize=32, pad=20)
        pos_edge = mpatches.Patch(color='#2b8cbe', label='Положительное влияние (усиливает)')
        neg_edge = mpatches.Patch(color='#e41a1c', label='Отрицательное влияние (ослабляет)')
        legend = plt.legend(handles=[pos_edge, neg_edge], fontsize=16, loc='upper right')
        plt.show()

# --- ИСПОЛЬЗОВАНИЕ КЛАССА ---

concepts_to_model = [
    'procrastination_freq', 'procrastination_impact', 'anxiety_stress',
    'motivation', 'deadline_dependency', 'sleep_impact', 'social_media',
    'caffeine', 'environment', 'self_esteem', 'fatigue'
]
train_df, test_df = train_test_split(df[concepts_to_model], test_size=0.25, random_state=42)

# Создаем "тренера" для нашей финальной модели
trainer = CognitiveMapTrainer(concepts=concepts_to_model)

# Обучаем модель. Можно поиграть с lr и weight_decay
trainer.train(train_df, epochs=500, lr=0.001, weight_decay=1e-4)

# Оцениваем качество
trainer.evaluate(test_df)

# Проводим сценарный анализ
trainer.run_scenario(interventions={'fatigue': 1, 'motivation': 5})

# Визуализируем финальную карту
trainer.visualize_graph()
# Out:
# --- Начало обучения нелинейной модели ---
# Эпоха 50/500, Потеря (Loss): 0.063082
# Эпоха 100/500, Потеря (Loss): 0.052842
# Эпоха 150/500, Потеря (Loss): 0.061130
# Эпоха 200/500, Потеря (Loss): 0.052214
# Эпоха 250/500, Потеря (Loss): 0.036684
# Эпоха 300/500, Потеря (Loss): 0.017815
# Эпоха 350/500, Потеря (Loss): 0.037398
# Эпоха 400/500, Потеря (Loss): 0.029537
# Эпоха 450/500, Потеря (Loss): 0.027461
# Эпоха 500/500, Потеря (Loss): 0.025083
# --- Обучение завершено ---
#
# --- Оценка качества на тестовых данных ---
# Среднеквадратичная ошибка (RMSE): 0.699
# Коэффициент детерминации (R²): 0.586
#   -> Модель объясняет 58.6% вариативности.
#
# --- Моделирование сценария 'Что, если?' ---
# Базовый уровень прокрастинации: 3.86
# Применены интервенции (зафиксированы значения):
#   - fatigue = 1
#   - motivation = 5
# Новый уровень прокрастинации: 3.75 (Изменение: -0.11)
#
# Визуализация обученной карты влияния...
